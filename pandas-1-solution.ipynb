# %% [markdown]
# # Loading data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## pandas.Series
#
# `Series` one dimensional array containing data and index, the same as one column in excel table.

# %%
age = pd.Series([19, 25, 18, 29], index=['Anna', 'Emily', 'Hannah', 'Julie'])

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age
# Out:
# Anna      19
# Emily     25
# Hannah    18
# Julie     29
# dtype: int64

# %%
age.index
# Out:
# Index(['Anna', 'Emily', 'Hannah', 'Julie'], dtype='object')

# %%
age.values
# Out:
# array([19, 25, 18, 29])

# %% [markdown]
# temperature
# index = '2018-12-03'
# values = 8.0

# %%
temperature = pd.Series(
    [8.0, 7.5, -1.0, 2.0], 
    index=['2018-12-03', '2018-12-04', '2018-12-05', '2018-12-06']
)

# %%
temperature.subtract(temperature.mean())
# Out:
# 2018-12-03    3.875
# 2018-12-04    3.375
# 2018-12-05   -5.125
# 2018-12-06   -2.125
# dtype: float64

# %%
temperature.mean()
# Out:
# 4.125

# %%
age.sort_values()
# Out:
# Hannah    18
# Anna      19
# Emily     25
# Julie     29
# dtype: int64

# %%
age.subtract(18)
# Out:
# Anna       1
# Emily      7
# Hannah     0
# Julie     11
# dtype: int64

# %% [markdown]
# ### `Series` has attributes and methods

# %%
age.name = 'agee' # name is an attribute

# %%
age
# Out:
# Anna      19
# Emily     25
# Hannah    18
# Julie     29
# Name: agee, dtype: int64

# %%
age = age.rename('age') # rename is method

# %%
age
# Out:
# Anna      19
# Emily     25
# Hannah    18
# Julie     29
# Name: age, dtype: int64

# %% [markdown]
# ### Loading data from `dict`

# %%
movies = {
    'Pavla':'Star Wars', 'Peter':'Star Trek', 'Jakub':'Star Wars', 'Claire':'Star Wars', 
    'Carol':'Star Trek', 'David':'Star Trek', 'Jan':'Star Trek', 'Filip':'Star Trek', 
    'Daniel':'Star Trek', 'Michaela':'Star Wars', 'James':'Star Trek'
}
movies_series  = pd.Series(movies)
movies_series
# Out:
# Pavla       Star Wars
# Peter       Star Trek
# Jakub       Star Wars
# Claire      Star Wars
# Carol       Star Trek
# David       Star Trek
# Jan         Star Trek
# Filip       Star Trek
# Daniel      Star Trek
# Michaela    Star Wars
# James       Star Trek
# dtype: object

# %% [markdown]
# ### Accessing elements of  `Series`

# %%
age[0]
# Out:
# 19

# %%
age['Anna']
# Out:
# 19

# %% [markdown]
# ### Exercise
#
# Create `pandas.Series` from the list of exam scores `[12, 33, 23, 15, 67]` for `['John', 'Emily', 'Jack', 'David', 'Matthew']`
#
# 1. Add name 'scores' attribute to it
# 2. Extract second element and store it as an variable
# 3. Extract Jack's exam scores

# %%
exam_scores = pd.Series([12, 33, 23, 15, 67], index=['John', 'Emily', 'Jack', 'David', 'Matthew'])
exam_scores
# Out:
# John       12
# Emily      33
# Jack       23
# David      15
# Matthew    67
# dtype: int64

# %%
exam_scores.name = 'scores'

# %%
emily_scores = exam_scores[1]
emily_scores
# Out:
# 33

# %%
jack_scores = exam_scores['Jack']
jack_scores
# Out:
# 23

# %% [markdown]
# ###  `Series` as array

# %%
age = pd.Series([19, 25, 18, 29], index=['Anna', 'Emily', 'Hannah', 'Julie'])

# %%
age.median()
# Out:
# 22.0

# %%
age > age.median()
# Out:
# Anna      False
# Emily      True
# Hannah    False
# Julie      True
# dtype: bool

# %%
age[age >= age.min()]
# Out:
# Anna      19
# Emily     25
# Hannah    18
# Julie     29
# dtype: int64

# %% [markdown]
# ### Vector operation with `Series`

# %%
# Number of selled ice cream scoops
ice_cream1 = pd.Series([30, 45, 55, 65], index=[
    'Chocolate', 'Strawberry', 'Vanilla', 'Straciatella'
])

# %%
# Number of selled scoops after campaign
ice_cream2 = pd.Series([110, 4, 150, 175], index=[
    'Chocolate', 'Strawberry', 'Vanilla', 'Straciatella'
])

# %%
ice_cream2 - ice_cream1
# Out:
# Chocolate        80
# Strawberry      -41
# Vanilla          95
# Straciatella    110
# dtype: int64

# %%
# If each scoop costs 35 CZK, how much money did we get?
price = 35
price * ice_cream1
# Out:
# Chocolate       1050
# Strawberry      1575
# Vanilla         1925
# Straciatella    2275
# dtype: int64

# %%
# What if strawberry costs 40 CZK, how much did we get for it?
price * ice_cream1['Strawberry']
# Out:
# 1575

# %% [markdown]
# ### Exercise
#
# Write a function that compares if the elements of the first `pandas.Series` are greater than elements of the secon `pandas.Series` and **print** number of time it is true.
# ```python
# >>> series1_is_greater_than_series2(series1, series2)
# 1
# ```

# %% [markdown]
# ```python
# def series1_is_greater_than_series2(series1, series2):
#     # put your code here
# ```

# %%
def series1_is_greater_than_series2(series1, series2):
    print(sum(series1 > series2))

# %%
series1_is_greater_than_series2(ice_cream1, ice_cream2)
# Out:
# 1

# %% [markdown]
# ## DataFrame

# %% [markdown]
# Two-dimensional data structure containing indexed rows and columns, the same as excel table.
#
# `DataFrame` can be created from `dict`, nested list, several `Series`, another `DataFrame`, etc.

# %%
movies = {
    'Pavla':'Star Wars', 'Peter':'Star Trek', 'Jakub':'Star Wars', 'Claire':'Star Wars', 
    'Carol':'Star Trek', 'David':'Star Trek', 'Jan':'Star Trek', 'Filip':'Star Trek', 
    'Daniel':'Star Trek', 'Michaela':'Star Wars', 'James':'Star Trek'
}
movies_df = pd.DataFrame(movies, index = range(0, len(movies)))

# %%
movies_df
# Out:
#         Pavla      Peter      Jakub     Claire      Carol      David  \
# 0   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 1   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 2   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 3   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 4   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 5   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 6   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 7   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 8   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 9   Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
# 10  Star Wars  Star Trek  Star Wars  Star Wars  Star Trek  Star Trek
#
#           Jan      Filip     Daniel   Michaela      James
# 0   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 1   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 2   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 3   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 4   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 5   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 6   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 7   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 8   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 9   Star Trek  Star Trek  Star Trek  Star Wars  Star Trek
# 10  Star Trek  Star Trek  Star Trek  Star Wars  Star Trek

# %%
# Not quite the way we wanted, let's specify that the data orientation is index
movies_df2 = pd.DataFrame.from_dict(movies, orient = 'index')
movies_df2
# Out:
#                   0
# Pavla     Star Wars
# Peter     Star Trek
# Jakub     Star Wars
# Claire    Star Wars
# Carol     Star Trek
# David     Star Trek
# Jan       Star Trek
# Filip     Star Trek
# Daniel    Star Trek
# Michaela  Star Wars
# James     Star Trek

# %%
movies_df2.reset_index(inplace=True)

# %%
movies_df2
# Out:
#        index          0
# 0      Pavla  Star Wars
# 1      Peter  Star Trek
# 2      Jakub  Star Wars
# 3     Claire  Star Wars
# 4      Carol  Star Trek
# 5      David  Star Trek
# 6        Jan  Star Trek
# 7      Filip  Star Trek
# 8     Daniel  Star Trek
# 9   Michaela  Star Wars
# 10     James  Star Trek

# %%
movies_df2.columns = ['Name', 'Movie']

# %%
movies_df2.head()
# Out:
#      Name      Movie
# 0   Pavla  Star Wars
# 1   Peter  Star Trek
# 2   Jakub  Star Wars
# 3  Claire  Star Wars
# 4   Carol  Star Trek

# %%
movies_df2.tail()
# Out:
#         Name      Movie
# 6        Jan  Star Trek
# 7      Filip  Star Trek
# 8     Daniel  Star Trek
# 9   Michaela  Star Wars
# 10     James  Star Trek

# %%
ice_cream1 = pd.Series([30, 45, 55, 65], 
                       index=['Chocolate', 'Strawberry', 'Vanilla', 'Straciatella'], 
                       name = '2017'
)
ice_cream2 = pd.Series([110, 120, 150, 175], 
                       index=['Chocolate', 'Strawberry', 'Vanilla', 'Straciatella'],
                      name = '2018'
) 
ice_cream_df = pd.concat([ice_cream1, ice_cream2], axis=1)
ice_cream_df
# Out:
#               2017  2018
# Chocolate       30   110
# Strawberry      45   120
# Vanilla         55   150
# Straciatella    65   175

# %%
ice_cream_df.describe()
# Out:
#             2017        2018
# count   4.000000    4.000000
# mean   48.750000  138.750000
# std    14.930394   29.545163
# min    30.000000  110.000000
# 25%    41.250000  117.500000
# 50%    50.000000  135.000000
# 75%    57.500000  156.250000
# max    65.000000  175.000000

# %%
import datetime
np.datetime64('2012-06-18T02:00:06.453000000')-np.datetime64('2012-06-18T02:00:05.453000000')
# Out:
# numpy.timedelta64(1000000000,'ns')

# %%
datetime.datetime(2018,10,12,8,0,0)
# Out:
# datetime.datetime(2018, 10, 12, 8, 0)

# %%
np.datetime64('2012-06-18T02:00:05.453000000')
# Out:
# numpy.datetime64('2012-06-18T02:00:05.453000000')

# %% [markdown]
# ### Exercise
#
# Create `pandas.DataFrame` from the data from previous exercise (scores`[12, 33, 23, 15, 67]` for `['John', 'Emily', 'Jack', 'David', 'Matthew']`).
#
# 1. Add column names = `Scores` and `Name`
# 2. Compute descriptive statistics for `Scores` column

# %%
scores = pd.Series([12, 33, 23, 15, 67], index=['John', 'Emily', 'Jack', 'David', 'Matthew'])
scores
# Out:
# John       12
# Emily      33
# Jack       23
# David      15
# Matthew    67
# dtype: int64

# %%
df = pd.DataFrame(scores)

# %%
df.reset_index(inplace=True)
df.columns = ['Name', 'Scores']

# %%
df.head()
# Out:
#       Name  Scores
# 0     John      12
# 1    Emily      33
# 2     Jack      23
# 3    David      15
# 4  Matthew      67

# %%
df.Scores.describe()
# Out:
# count     5.000000
# mean     30.000000
# std      22.226111
# min      12.000000
# 25%      15.000000
# 50%      23.000000
# 75%      33.000000
# max      67.000000
# Name: Scores, dtype: float64

# %% [markdown]
# ## Loading data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### CSV import

# %%
wolf_data = pd.read_csv(
    'http://vincentarelbundock.github.io/Rdatasets/csv/carData/Depredations.csv', index_col = 0
)
wolf_data.head()
# Out:
#    longitude  latitude  number  early  late
# 1      -94.5      46.1       1      0     1
# 2      -93.0      46.6       2      0     2
# 3      -94.6      48.5       1      1     0
# 4      -92.9      46.6       2      0     2
# 5      -95.9      48.8       1      0     1

# %% [markdown]
# #### Clipboard import

# %%
data_clipboard = pd.read_clipboard()
data_clipboard
# Out:
#    emily_scores   =  exam_scores[1]
# 0  emily_scores NaN             NaN

# %% [markdown]
# ####  TXT and TSV table import

# %%
titanic_train = pd.read_table(
    'http://www.statsci.org/data/general/titanic.txt')
titanic_train.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %% [markdown]
# #### JSON import
#
# Data from Czech hydrometeorological institute - air quality
#
# We want to extract various air quality measurements from different parts of Czech republic and then load them as `DataFrame`.

# %%
import requests

# %%
response = requests.get('http://portal.chmi.cz/files/portal/docs/uoco/web_generator/aqindex_cze.json')
chmi_air = response.json()
chmi_air
# Out:
# {'Actualized': '12.12.2018 15:48 SEČ',
#  'Components': [{'Code': 'SO2', 'Name': 'oxid siřičitý', 'Unit': 'µg/m³'},
#   {'Code': 'NO2', 'Name': 'oxid dusičitý', 'Unit': 'µg/m³'},
#   {'Code': 'CO', 'Name': 'oxid uhelnatý', 'Unit': 'µg/m³'},
#   {'Code': 'O3', 'Name': 'ozon', 'Unit': 'µg/m³'},
#   {'Code': 'PM10', 'Name': 'částice PM10', 'Unit': 'µg/m³'},
#   {'Code': 'PM2_5', 'Name': 'jemné částice PM2,5', 'Unit': 'µg/m³'}],
#  'IsOzoneUsedInIndex': False,
#  'Legend': [{'Color': 'C7EAFB',
#    'ColorText': '000000',
#    'Description': 'velmi dobrá',
#    'Ix': 1},
#   {'Color': '9BD3AE', 'ColorText': '000000', 'Description': 'dobrá', 'Ix': 2},
#   {'Color': 'FFF200',
#    'ColorText': '000000',
#    'Description': 'uspokojivá',
#    'Ix': 3},
#   {'Color': 'FAA61A',
#    'ColorText': '000000',
#    'Description': 'vyhovující',
#    'Ix': 4},
#   {'Color': 'ED1C24', 'ColorText': 'FFFFFF', 'Description': 'špatná', 'Ix': 5},
#   {'Color': '671F20',
#    'ColorText': 'FFFFFF',
#    'Description': 'velmi špatná',
#    'Ix': 6},
#   {'Color': 'FFFFFF',
#    'ColorText': '000000',
#    'Description': 'Neúplná data',
#    'Ix': 0},
#   {'Color': 'CFCFCF',
#    'ColorText': '000000',
#    'Description': 'Index se na uvedené stanici nestanovuje',
#    'Ix': -1}],
#  'Note': 'Encoded in UTF-8. Contact vanek(@)idea-envi.cz if you need JAVA code to read this JSON',
#  'States': [{'Code': 'CZ',
#    'DateFromTo': '12.12.2018 14:00 - 15:00 SEČ',
#    'DateFromUTC': '2018-12-12 13:00:00.0 UTC',
#    'DateToUTC': '2018-12-12 14:00:00.0 UTC',
#    'Name': 'Česká republika',
#    'Regions': [{'Code': 'A',
#      'Name': 'Praha',
#      'Stations': [{'Classif': '',
#        'Code': '',
#        'Ix': 2,
#        'Name': 'Střed Prahy',
#        'Owner': ''},
#       {'Classif': 'dopravní',
#        'Code': 'AKALA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 0,
#        'Lat': '50.094238',
#        'Lon': '14.442049',
#        'Name': 'Praha 8-Karlín',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'ALEGA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 3, 'Val': '67.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '356'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '15.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#        'Ix': 3,
#        'Lat': '50.072388',
#        'Lon': '14.430673',
#        'Name': 'Praha 2-Legerova (hot spot)',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'AREPA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '40.2'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '23.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.6'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 2,
#        'Lat': '50.088066',
#        'Lon': '14.429220',
#        'Name': 'Praha 1-n. Republiky',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'ARIEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.7'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '36.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '32.0'}],
#        'Ix': 1,
#        'Lat': '50.081482',
#        'Lon': '14.442692',
#        'Name': 'Praha 2-Riegrovy sady',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'ASMIA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '30.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.5'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '6.0'}],
#        'Ix': 2,
#        'Lat': '50.073135',
#        'Lon': '14.398141',
#        'Name': 'Praha 5-Smíchov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'AVRSA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.2'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.066429',
#        'Lon': '14.446152',
#        'Name': 'Praha 10-Vršovice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'AVYNA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '49.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '19.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '19.8'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 2,
#        'Lat': '50.111080',
#        'Lon': '14.503096',
#        'Name': 'Praha 9-Vysočany',
#        'Owner': 'ČHMÚ'},
#       {'Classif': '', 'Code': '', 'Ix': 1, 'Name': 'Okraj Prahy', 'Owner': ''},
#       {'Classif': 'předměstská',
#        'Code': 'AKOBA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '19.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '37.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.122189',
#        'Lon': '14.467578',
#        'Name': 'Praha 8-Kobylisy',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'ALIBA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '15.3'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '297'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.3'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '44.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '5.1'}],
#        'Ix': 1,
#        'Lat': '50.007305',
#        'Lon': '14.445933',
#        'Name': 'Praha 4-Libuš',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'ASTOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '30.3'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#        'Ix': 1,
#        'Lat': '50.046131',
#        'Lon': '14.331413',
#        'Name': 'Praha 5-Stodůlky',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'ASUCA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.7'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.126530',
#        'Lon': '14.384639',
#        'Name': 'Praha 6-Suchdol',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'ABREA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '32.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 2,
#        'Lat': '50.084385',
#        'Lon': '14.380116',
#        'Name': 'Praha 6-Břevnov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'ACHOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '16.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '18.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.5'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.030170',
#        'Lon': '14.517450',
#        'Name': 'Praha 4-Chodov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'ALERA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '14.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '14.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.2'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '6.0'}],
#        'Ix': 1,
#        'Lat': '50.107086',
#        'Lon': '14.257226',
#        'Name': 'Letiště Praha',
#        'Owner': 'Letiště Pr'},
#       {'Classif': 'dopravní',
#        'Code': 'APRUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.8'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.062298',
#        'Lon': '14.537820',
#        'Name': 'Praha 10-Průmyslová',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'ARERA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '15.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.5'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '8.0'}],
#        'Ix': 1,
#        'Lat': '50.030418',
#        'Lon': '14.309517',
#        'Name': 'Praha 5-Řeporyje',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'městská',
#        'Code': 'ASROA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.6'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#        'Ix': 1,
#        'Lat': '50.075150',
#        'Lon': '14.472661',
#        'Name': 'Praha 10-Šrobárova',
#        'Owner': 'ZÚUstí/SZÚ'}]},
#     {'Code': 'S',
#      'Name': 'Středočeský',
#      'Stations': [{'Classif': 'dopravní',
#        'Code': 'SBERA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.4'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '344'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#        'Ix': 1,
#        'Lat': '49.957928',
#        'Lon': '14.058300',
#        'Name': 'Beroun',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'SKHOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '49.950474',
#        'Lon': '15.260361',
#        'Name': 'Kutná Hora-Orebitská',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'SKLMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '20.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.8'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#        'Ix': 1,
#        'Lat': '50.143860',
#        'Lon': '14.101784',
#        'Name': 'Kladno-střed města',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'SKLSA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '15.4'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.6'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '12.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '16.8'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.167412',
#        'Lon': '14.106048',
#        'Name': 'Kladno-Švermov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'průmyslová',
#        'Code': 'SKRPA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#        'Ix': 1,
#        'Lat': '50.251415',
#        'Lon': '14.316583',
#        'Name': 'Kralupy nad Vltavou-sportoviště',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'městská',
#        'Code': 'SMBOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '50.428646',
#        'Lon': '14.913859',
#        'Name': 'Mladá Boleslav',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'SONRA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '55.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '49.913513',
#        'Lon': '14.782625',
#        'Name': 'Ondřejov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'SPBRA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '49.676315',
#        'Lon': '13.991222',
#        'Name': 'Příbram-Březové Hory',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'SRORA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '50.301983',
#        'Lon': '15.178303',
#        'Name': 'Rožďalovice-Ruská',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'STCSA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '10.9'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '255'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '29.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.0'}],
#        'Ix': -1,
#        'Lat': '49.918503',
#        'Lon': '14.094489',
#        'Name': 'Tobolka-Čertovy schody',
#        'Owner': 'VČs'}]},
#     {'Code': 'C',
#      'Name': 'Jihočeský',
#      'Stations': [{'Classif': 'městská',
#        'Code': 'CCBDA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '12.4'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#        'Ix': 0,
#        'Lat': '48.984386',
#        'Lon': '14.465684',
#        'Name': 'České Budějovice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'CCBTA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '8.0'}],
#        'Ix': 1,
#        'Lat': '48.965904',
#        'Lon': '14.508792',
#        'Name': 'Čes. Budějovice-Třešň.',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'venkovská',
#        'Code': 'CCHUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.1'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '39.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': -1,
#        'Lat': '49.068436',
#        'Lon': '13.614801',
#        'Name': 'Churáňov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'CHVOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '26.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '48.724197',
#        'Lon': '14.723382',
#        'Name': 'Hojná Voda',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'CKOCA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '28.3'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '49.467274',
#        'Lon': '13.837456',
#        'Name': 'Kocelovice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'CPRAA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '14.7'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '28.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.2'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '49.016087',
#        'Lon': '14.000444',
#        'Name': 'Prachatice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'CTABA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '19.3'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '253'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '17.6'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.5'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '49.411232',
#        'Lon': '14.676389',
#        'Name': 'Tábor',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'P',
#      'Name': 'Plzeňský',
#      'Stations': [{'Classif': 'dopravní',
#        'Code': 'PKLSA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#        'Ix': 1,
#        'Lat': '49.400608',
#        'Lon': '13.286923',
#        'Name': 'Klatovy soud',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'venkovská',
#        'Code': 'PKUJA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '9.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.4'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#        'Ix': 1,
#        'Lat': '49.722000',
#        'Lon': '13.618538',
#        'Name': 'Kamenný Újezd',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'PPLAA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '184'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '39.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '5.8'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '10.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '11.0'}],
#        'Ix': 0,
#        'Lat': '49.732449',
#        'Lon': '13.402281',
#        'Name': 'Plzeň-Slovany',
#        'Owner': 'MPl'},
#       {'Classif': 'dopravní',
#        'Code': 'PPLEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '20.0'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '20.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '17.0'}],
#        'Ix': 1,
#        'Lat': '49.747330',
#        'Lon': '13.381039',
#        'Name': 'Plzeň-střed',
#        'Owner': 'MPl'},
#       {'Classif': 'městská',
#        'Code': 'PPLLA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '14.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '23.7'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '15.2'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.7'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#        'Ix': 1,
#        'Lat': '49.770126',
#        'Lon': '13.368221',
#        'Name': 'Plzeň-Lochotín',
#        'Owner': 'MPl'},
#       {'Classif': 'městská',
#        'Code': 'PPLRA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '17.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.0'}],
#        'Ix': 1,
#        'Lat': '49.761787',
#        'Lon': '13.381614',
#        'Name': 'Plzeň-Roudná',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'předměstská',
#        'Code': 'PPLVA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '3.2'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.9'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.7'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#        'Ix': 1,
#        'Lat': '49.768616',
#        'Lon': '13.423381',
#        'Name': 'Plzeň-Doubravka',
#        'Owner': 'ČHMÚ'},
#       {'Classif': '',
#        'Code': 'PPMOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '29.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '520'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '27.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '6.2'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.6'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '24.0'}],
#        'Ix': 2,
#        'Lat': '49.738586',
#        'Lon': '13.387257',
#        'Name': 'Plzeň - mobil 18.10.2017 Plzeň - Mikulášské náměstí',
#        'Owner': 'MPl'},
#       {'Classif': 'venkovská',
#        'Code': 'PPRMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '30.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '49.669582',
#        'Lon': '12.677884',
#        'Name': 'Přimda',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'K',
#      'Name': 'Karlovarský',
#      'Stations': [{'Classif': 'předměstská',
#        'Code': 'KCHMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.065861',
#        'Lon': '12.363442',
#        'Name': 'Cheb',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'KPRBA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.6'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '43.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.372478',
#        'Lon': '12.615380',
#        'Name': 'Přebuz',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'KSOMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '6.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.6'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '31.3'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#        'Ix': 1,
#        'Lat': '50.172825',
#        'Lon': '12.672818',
#        'Name': 'Sokolov',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'U',
#      'Name': 'Ústecký',
#      'Stations': [{'Classif': 'městská',
#        'Code': 'UCHMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.467529',
#        'Lon': '13.412696',
#        'Name': 'Chomutov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'UDCMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.6'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.6'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#        'Ix': 1,
#        'Lat': '50.774151',
#        'Lon': '14.218794',
#        'Name': 'Děčín',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'UDOKA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '6.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '41.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.458855',
#        'Lon': '14.170162',
#        'Name': 'Doksany',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'UKRUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.6'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.696671',
#        'Lon': '13.847692',
#        'Name': 'Krupka',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'ULOMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '6.7'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '13.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '39.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#        'Ix': 1,
#        'Lat': '50.585766',
#        'Lon': '13.673418',
#        'Name': 'Lom',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'ULTTA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.540897',
#        'Lon': '14.119409',
#        'Name': 'Litoměřice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'UMEDA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.427589',
#        'Lon': '13.130143',
#        'Name': 'Měděnec',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'UMOMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '16.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '29.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.2'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#        'Ix': 1,
#        'Lat': '50.510365',
#        'Lon': '13.645272',
#        'Name': 'Most',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'URVHA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '44.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.579834',
#        'Lon': '13.419506',
#        'Name': 'Rudolice v Horách',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'USNZA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.7'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '43.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.789444',
#        'Lon': '14.086799',
#        'Name': 'Sněžník',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'USTEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '6.1'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '21.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '19.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '26.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.8'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '16.0'}],
#        'Ix': 1,
#        'Lat': '50.454155',
#        'Lon': '14.374163',
#        'Name': 'Štětí',
#        'Owner': 'MSTE'},
#       {'Classif': 'městská',
#        'Code': 'UTPMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '37.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#        'Ix': 1,
#        'Lat': '50.645279',
#        'Lon': '13.851250',
#        'Name': 'Teplice ',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'UTUSA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '1.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '38.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '9.0'}],
#        'Ix': 1,
#        'Lat': '50.376587',
#        'Lon': '13.327622',
#        'Name': 'Tušimice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'průmyslová',
#        'Code': 'UUDIA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#        'Ix': 1,
#        'Lat': '50.662979',
#        'Lon': '14.031243',
#        'Name': 'Ústí n. L.-Prokopa Diviše',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'dopravní',
#        'Code': 'UULDA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '359'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '12.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#        'Ix': 0,
#        'Lat': '50.683125',
#        'Lon': '13.997873',
#        'Name': 'Ústí n.L.-Všebořická (hot spot)',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'UULKA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '42.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.9'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#        'Ix': 1,
#        'Lat': '50.683525',
#        'Lon': '14.041195',
#        'Name': 'Ústí n.L.-Kočkov',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'UULMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '10.7'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.661095',
#        'Lon': '14.043063',
#        'Name': 'Ústí n.L.-město',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'L',
#      'Name': 'Liberecký',
#      'Stations': [{'Classif': 'městská',
#        'Code': 'LCLMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '50.698044',
#        'Lon': '14.537345',
#        'Name': 'Česká Lípa',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'LFRTA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '41.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.940651',
#        'Lon': '15.069817',
#        'Name': 'Frýdlant',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'LLILA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '21.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '17.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '31.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.8'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#        'Ix': 1,
#        'Lat': '50.755100',
#        'Lon': '15.069967',
#        'Name': 'Liberec Rochlice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'LSOUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '53.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.789646',
#        'Lon': '15.319683',
#        'Name': 'Souš',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'H',
#      'Name': 'Královéhradecký',
#      'Stations': [{'Classif': 'dopravní',
#        'Code': 'HHKBA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '50.195362',
#        'Lon': '15.846376',
#        'Name': 'Hradec Králové-Brněnská',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'HHKOK',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.177631',
#        'Lon': '15.838390',
#        'Name': 'Hradec Králové-observatoř',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'HHKSA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '50.211700',
#        'Lon': '15.814149',
#        'Name': 'Hr.Král.-Sukovy sady',
#        'Owner': 'ZÚ Ústí nL'},
#       {'Classif': 'venkovská',
#        'Code': 'HKRYA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.660439',
#        'Lon': '15.850090',
#        'Name': 'Krkonoše-Rýchory',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'HPLOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 0,
#        'Lat': '50.350563',
#        'Lon': '16.322727',
#        'Name': 'Polom',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'HTRTA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 0,
#        'Lat': '50.565880',
#        'Lon': '15.903927',
#        'Name': 'Trutnov - Tkalcovská',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'E',
#      'Name': 'Pardubický',
#      'Stations': [{'Classif': 'městská',
#        'Code': 'EMTPA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '49.758995',
#        'Lon': '16.666721',
#        'Name': 'Moravská Třebová - Piaristická.',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'předměstská',
#        'Code': 'EPAOA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '50.042198',
#        'Lon': '15.739414',
#        'Name': 'Pardubice-Rosice',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'městská',
#        'Code': 'EPAUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '50.024036',
#        'Lon': '15.763549',
#        'Name': 'Pardubice Dukla',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'venkovská',
#        'Code': 'ESVRA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '49.735085',
#        'Lon': '16.034197',
#        'Name': 'Svratouch',
#        'Owner': 'ČHMÚ'}]},
#     {'Code': 'J',
#      'Name': 'Vysočina',
#      'Stations': [{'Classif': 'městská',
#        'Code': 'JJIHA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '245'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '13.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '41.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '9.0'}],
#        'Ix': 1,
#        'Lat': '49.401596',
#        'Lon': '15.610246',
#        'Name': 'Jihlava',
#        'Owner': 'ČHMÚ'},
#       {'Classif': 'dopravní',
#        'Code': 'JJIZA',
# ...
#        'Lon': '15.020000',
#        'Name': 'Trasdorf',
#        'Owner': 'Amt der NÖ'},
#       {'Classif': 'venkovská',
#        'Code': '2TUKA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '6.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '48.270000',
#        'Lon': '16.129999',
#        'Name': 'Tulbinger Kogel',
#        'Owner': 'Amt der NÖ'},
#       {'Classif': 'městská',
#        'Code': '2TULA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.5'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.5'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '14.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '48.330002',
#        'Lon': '16.062000',
#        'Name': 'Tulln',
#        'Owner': 'Amt der NÖ'},
#       {'Classif': 'venkovská',
#        'Code': '2WOLA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '13.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '16.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '48.380001',
#        'Lon': '16.510000',
#        'Name': 'Wolkersdorf',
#        'Owner': 'Amt der NÖ'},
#       {'Classif': 'venkovská',
#        'Code': '2ZIEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '2.5'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '28.0'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.4'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': 1,
#        'Lat': '48.528702',
#        'Lon': '15.942300',
#        'Name': 'Ziersdorf',
#        'Owner': 'Amt der NÖ'},
#       {'Classif': 'předměstská',
#        'Code': '2ZWEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '2.0'}],
#        'Ix': -1,
#        'Lat': '48.330002',
#        'Lon': '15.900000',
#        'Name': 'Zwentendorf',
#        'Owner': 'Amt der NÖ'}]},
#     {'Code': '3',
#      'Name': 'Horní Rakousko',
#      'Stations': [{'Classif': '',
#        'Code': '3ASEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '14.414708',
#        'Lon': '48.221832',
#        'Name': 'Asten',
#        'Owner': 'AOL'},
#       {'Classif': 'předměstská',
#        'Code': '3BISA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '25.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '46.8'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.4'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.9'}],
#        'Ix': 2,
#        'Lat': '47.716194',
#        'Lon': '13.632270',
#        'Name': 'Bad-Ischl',
#        'Owner': 'AOL'},
#       {'Classif': 'předměstská',
#        'Code': '3BZEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '28.9'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '22.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '11.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '15.2'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '19.2'}],
#        'Ix': 2,
#        'Lat': '48.391624',
#        'Lon': '13.670844',
#        'Name': 'Braunau Zentrum',
#        'Owner': 'AOL'},
#       {'Classif': 'dopravní',
#        'Code': '3EKRA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 3, 'Val': '52.9'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '266'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '21.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '14.5'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '16.2'}],
#        'Ix': 3,
#        'Lat': '48.208084',
#        'Lon': '14.436930',
#        'Name': 'Enns-Kristein 3',
#        'Owner': 'AOL'},
#       {'Classif': '',
#        'Code': '3ENZA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '26.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '47.815853',
#        'Lon': '13.720737',
#        'Name': 'Enzenkirchen',
#        'Owner': 'AOL'},
#       {'Classif': '',
#        'Code': '3FEUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '0.9'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '48.8'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '0.6'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '0.8'}],
#        'Ix': 0,
#        'Lat': '47.815853',
#        'Lon': '13.720737',
#        'Name': 'Feuerkogel',
#        'Owner': 'AOL'},
#       {'Classif': 'venkovská',
#        'Code': '3GRNA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '0.7'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.6'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '36.0'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.8'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '2.9'}],
#        'Ix': 0,
#        'Lat': '48.253765',
#        'Lon': '14.310166',
#        'Name': 'Grünbach',
#        'Owner': 'AOL'},
#       {'Classif': '',
#        'Code': '3HAIA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '20.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '236'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '20.3'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '11.7'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '19.1'}],
#        'Ix': 2,
#        'Lat': '14.243884',
#        'Lon': '48.197090',
#        'Name': 'Haid',
#        'Owner': 'AOL'},
#       {'Classif': 'průmyslová',
#        'Code': '3LENA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '0.3'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '11.8'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '50.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '47.971832',
#        'Lon': '13.600619',
#        'Name': 'Lenzing',
#        'Owner': 'AOL'},
#       {'Classif': '',
#        'Code': '3LEZA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '13.609031',
#        'Lon': '47.974148',
#        'Name': 'Lenzing 2',
#        'Owner': 'AOL'},
#       {'Classif': 'městská',
#        'Code': '3LNWA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '0.8'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '29.5'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '268'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '16.1'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '14.3'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '13.2'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '14.0'}],
#        'Ix': 2,
#        'Lat': '48.273304',
#        'Lon': '14.314806',
#        'Name': 'Linz-Neue Welt',
#        'Owner': 'AOL'},
#       {'Classif': 'dopravní',
#        'Code': '3LRMA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '35.2'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '276'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '20.7'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '16.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '16.3'}],
#        'Ix': 2,
#        'Lat': '48.302990',
#        'Lon': '14.282153',
#        'Name': 'Linz-Römerbergtunnel',
#        'Owner': 'AOL'},
#       {'Classif': 'městská',
#        'Code': '3LSTA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '23.1'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '15.8'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '18.4'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.5'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.5'}],
#        'Ix': 1,
#        'Lat': '48.306190',
#        'Lon': '14.297203',
#        'Name': 'Linz-Stadtpark',
#        'Owner': 'AOL'},
#       {'Classif': 'dopravní',
#        'Code': '3LTUA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '48.225330',
#        'Lon': '14.237547',
#        'Name': 'Linz-24er-Turm',
#        'Owner': 'AOL'},
#       {'Classif': '',
#        'Code': '3RANA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '13.015250',
#        'Lon': '48.225082',
#        'Name': 'Ranshofen 3',
#        'Owner': 'AOL'},
#       {'Classif': '',
#        'Code': '3SCHA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#        'Ix': 0,
#        'Lat': '12.939203',
#        'Lon': '48.187473',
#        'Name': 'Schwand',
#        'Owner': 'AOL'},
#       {'Classif': 'průmyslová',
#        'Code': '3SGAA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '24.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.2'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '995'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '14.9'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '14.4'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.6'}],
#        'Ix': 1,
#        'Lat': '48.279739',
#        'Lon': '14.366507',
#        'Name': 'Steyregg-Au',
#        'Owner': 'AOL'},
#       {'Classif': 'předměstská',
#        'Code': '3STEA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.7'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '19.6'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.9'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '27.1'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '9.8'}],
#        'Ix': 1,
#        'Lat': '48.049240',
#        'Lon': '14.442225',
#        'Name': 'Steyr',
#        'Owner': 'AOL'},
#       {'Classif': 'předměstská',
#        'Code': '3TRAA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.2'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '14.3'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '21.9'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '11.0'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.3'}],
#        'Ix': 1,
#        'Lat': '48.225330',
#        'Lon': '14.237547',
#        'Name': 'Traun',
#        'Owner': 'AOL'},
#       {'Classif': 'předměstská',
#        'Code': '3VKLA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '0.9'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '15.3'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.1'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.7'}],
#        'Ix': 1,
#        'Lat': '48.000832',
#        'Lon': '13.667314',
#        'Name': 'Vöcklabruck',
#        'Owner': 'AOL'},
#       {'Classif': 'městská',
#        'Code': '3WELA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.2'},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.3'},
#         {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '258'},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '14.6'},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '19.7'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '10.3'},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.1'}],
#        'Ix': 1,
#        'Lat': '48.164898',
#        'Lon': '14.036616',
#        'Name': 'Wels',
#        'Owner': 'AOL'},
#       {'Classif': 'venkovská',
#        'Code': '3ZBLA',
#        'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#         {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#         {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#         {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '40.5'},
#         {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#         {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#        'Ix': -1,
#        'Lat': '47.838612',
#        'Lon': '14.441389',
#        'Name': 'Zöbelboden 2',
#        'Owner': 'AOL'}]}]}],
#  'Version': 2}

# %%
czech = [state for state in chmi_air['States'] if state['Code'] == 'CZ']
czech[0]
# Out:
# {'Code': 'CZ',
#  'DateFromTo': '12.12.2018 14:00 - 15:00 SEČ',
#  'DateFromUTC': '2018-12-12 13:00:00.0 UTC',
#  'DateToUTC': '2018-12-12 14:00:00.0 UTC',
#  'Name': 'Česká republika',
#  'Regions': [{'Code': 'A',
#    'Name': 'Praha',
#    'Stations': [{'Classif': '',
#      'Code': '',
#      'Ix': 2,
#      'Name': 'Střed Prahy',
#      'Owner': ''},
#     {'Classif': 'dopravní',
#      'Code': 'AKALA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 0,
#      'Lat': '50.094238',
#      'Lon': '14.442049',
#      'Name': 'Praha 8-Karlín',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'ALEGA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 3, 'Val': '67.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '356'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '15.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#      'Ix': 3,
#      'Lat': '50.072388',
#      'Lon': '14.430673',
#      'Name': 'Praha 2-Legerova (hot spot)',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'AREPA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '40.2'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '23.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '50.088066',
#      'Lon': '14.429220',
#      'Name': 'Praha 1-n. Republiky',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'ARIEA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '36.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '32.0'}],
#      'Ix': 1,
#      'Lat': '50.081482',
#      'Lon': '14.442692',
#      'Name': 'Praha 2-Riegrovy sady',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'ASMIA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '30.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.5'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '6.0'}],
#      'Ix': 2,
#      'Lat': '50.073135',
#      'Lon': '14.398141',
#      'Name': 'Praha 5-Smíchov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'AVRSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.2'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.066429',
#      'Lon': '14.446152',
#      'Name': 'Praha 10-Vršovice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'AVYNA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '49.5'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '19.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '19.8'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '50.111080',
#      'Lon': '14.503096',
#      'Name': 'Praha 9-Vysočany',
#      'Owner': 'ČHMÚ'},
#     {'Classif': '', 'Code': '', 'Ix': 1, 'Name': 'Okraj Prahy', 'Owner': ''},
#     {'Classif': 'předměstská',
#      'Code': 'AKOBA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '19.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '37.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.122189',
#      'Lon': '14.467578',
#      'Name': 'Praha 8-Kobylisy',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'ALIBA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '15.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '297'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.3'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '44.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '5.1'}],
#      'Ix': 1,
#      'Lat': '50.007305',
#      'Lon': '14.445933',
#      'Name': 'Praha 4-Libuš',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'ASTOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '30.3'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#      'Ix': 1,
#      'Lat': '50.046131',
#      'Lon': '14.331413',
#      'Name': 'Praha 5-Stodůlky',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'ASUCA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.126530',
#      'Lon': '14.384639',
#      'Name': 'Praha 6-Suchdol',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'ABREA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '32.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '50.084385',
#      'Lon': '14.380116',
#      'Name': 'Praha 6-Břevnov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'ACHOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '16.8'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '18.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.5'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.030170',
#      'Lon': '14.517450',
#      'Name': 'Praha 4-Chodov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'ALERA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '14.5'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '14.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.2'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '6.0'}],
#      'Ix': 1,
#      'Lat': '50.107086',
#      'Lon': '14.257226',
#      'Name': 'Letiště Praha',
#      'Owner': 'Letiště Pr'},
#     {'Classif': 'dopravní',
#      'Code': 'APRUA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.062298',
#      'Lon': '14.537820',
#      'Name': 'Praha 10-Průmyslová',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'ARERA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '15.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.5'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '8.0'}],
#      'Ix': 1,
#      'Lat': '50.030418',
#      'Lon': '14.309517',
#      'Name': 'Praha 5-Řeporyje',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'městská',
#      'Code': 'ASROA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#      'Ix': 1,
#      'Lat': '50.075150',
#      'Lon': '14.472661',
#      'Name': 'Praha 10-Šrobárova',
#      'Owner': 'ZÚUstí/SZÚ'}]},
#   {'Code': 'S',
#    'Name': 'Středočeský',
#    'Stations': [{'Classif': 'dopravní',
#      'Code': 'SBERA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '344'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#      'Ix': 1,
#      'Lat': '49.957928',
#      'Lon': '14.058300',
#      'Name': 'Beroun',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'SKHOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '49.950474',
#      'Lon': '15.260361',
#      'Name': 'Kutná Hora-Orebitská',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'SKLMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '20.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#      'Ix': 1,
#      'Lat': '50.143860',
#      'Lon': '14.101784',
#      'Name': 'Kladno-střed města',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'SKLSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '15.4'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '12.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '16.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.167412',
#      'Lon': '14.106048',
#      'Name': 'Kladno-Švermov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'průmyslová',
#      'Code': 'SKRPA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#      'Ix': 1,
#      'Lat': '50.251415',
#      'Lon': '14.316583',
#      'Name': 'Kralupy nad Vltavou-sportoviště',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'městská',
#      'Code': 'SMBOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '50.428646',
#      'Lon': '14.913859',
#      'Name': 'Mladá Boleslav',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'SONRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '55.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.913513',
#      'Lon': '14.782625',
#      'Name': 'Ondřejov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'SPBRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '49.676315',
#      'Lon': '13.991222',
#      'Name': 'Příbram-Březové Hory',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'SRORA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '50.301983',
#      'Lon': '15.178303',
#      'Name': 'Rožďalovice-Ruská',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'STCSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '10.9'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '255'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '29.5'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.0'}],
#      'Ix': -1,
#      'Lat': '49.918503',
#      'Lon': '14.094489',
#      'Name': 'Tobolka-Čertovy schody',
#      'Owner': 'VČs'}]},
#   {'Code': 'C',
#    'Name': 'Jihočeský',
#    'Stations': [{'Classif': 'městská',
#      'Code': 'CCBDA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '12.4'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#      'Ix': 0,
#      'Lat': '48.984386',
#      'Lon': '14.465684',
#      'Name': 'České Budějovice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'CCBTA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '8.0'}],
#      'Ix': 1,
#      'Lat': '48.965904',
#      'Lon': '14.508792',
#      'Name': 'Čes. Budějovice-Třešň.',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'venkovská',
#      'Code': 'CCHUA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.1'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '39.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': -1,
#      'Lat': '49.068436',
#      'Lon': '13.614801',
#      'Name': 'Churáňov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'CHVOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '26.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '48.724197',
#      'Lon': '14.723382',
#      'Name': 'Hojná Voda',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'CKOCA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '28.3'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.467274',
#      'Lon': '13.837456',
#      'Name': 'Kocelovice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'CPRAA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '14.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '28.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.2'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '49.016087',
#      'Lon': '14.000444',
#      'Name': 'Prachatice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'CTABA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '19.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '253'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '17.6'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.5'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '49.411232',
#      'Lon': '14.676389',
#      'Name': 'Tábor',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'P',
#    'Name': 'Plzeňský',
#    'Stations': [{'Classif': 'dopravní',
#      'Code': 'PKLSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#      'Ix': 1,
#      'Lat': '49.400608',
#      'Lon': '13.286923',
#      'Name': 'Klatovy soud',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'venkovská',
#      'Code': 'PKUJA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '9.9'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '5.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#      'Ix': 1,
#      'Lat': '49.722000',
#      'Lon': '13.618538',
#      'Name': 'Kamenný Újezd',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'PPLAA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.9'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '184'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '39.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '5.8'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '10.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '11.0'}],
#      'Ix': 0,
#      'Lat': '49.732449',
#      'Lon': '13.402281',
#      'Name': 'Plzeň-Slovany',
#      'Owner': 'MPl'},
#     {'Classif': 'dopravní',
#      'Code': 'PPLEA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '20.0'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '20.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '17.0'}],
#      'Ix': 1,
#      'Lat': '49.747330',
#      'Lon': '13.381039',
#      'Name': 'Plzeň-střed',
#      'Owner': 'MPl'},
#     {'Classif': 'městská',
#      'Code': 'PPLLA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '14.9'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '23.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '15.2'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#      'Ix': 1,
#      'Lat': '49.770126',
#      'Lon': '13.368221',
#      'Name': 'Plzeň-Lochotín',
#      'Owner': 'MPl'},
#     {'Classif': 'městská',
#      'Code': 'PPLRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '17.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.0'}],
#      'Ix': 1,
#      'Lat': '49.761787',
#      'Lon': '13.381614',
#      'Name': 'Plzeň-Roudná',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'předměstská',
#      'Code': 'PPLVA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '3.2'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '24.9'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '8.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#      'Ix': 1,
#      'Lat': '49.768616',
#      'Lon': '13.423381',
#      'Name': 'Plzeň-Doubravka',
#      'Owner': 'ČHMÚ'},
#     {'Classif': '',
#      'Code': 'PPMOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '29.8'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '520'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '27.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '6.2'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '9.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '24.0'}],
#      'Ix': 2,
#      'Lat': '49.738586',
#      'Lon': '13.387257',
#      'Name': 'Plzeň - mobil 18.10.2017 Plzeň - Mikulášské náměstí',
#      'Owner': 'MPl'},
#     {'Classif': 'venkovská',
#      'Code': 'PPRMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '30.5'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.669582',
#      'Lon': '12.677884',
#      'Name': 'Přimda',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'K',
#    'Name': 'Karlovarský',
#    'Stations': [{'Classif': 'předměstská',
#      'Code': 'KCHMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.065861',
#      'Lon': '12.363442',
#      'Name': 'Cheb',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'KPRBA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '43.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.372478',
#      'Lon': '12.615380',
#      'Name': 'Přebuz',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'KSOMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '6.9'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '31.3'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#      'Ix': 1,
#      'Lat': '50.172825',
#      'Lon': '12.672818',
#      'Name': 'Sokolov',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'U',
#    'Name': 'Ústecký',
#    'Stations': [{'Classif': 'městská',
#      'Code': 'UCHMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '9.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.467529',
#      'Lon': '13.412696',
#      'Name': 'Chomutov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'UDCMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#      'Ix': 1,
#      'Lat': '50.774151',
#      'Lon': '14.218794',
#      'Name': 'Děčín',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'UDOKA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '6.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '41.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.458855',
#      'Lon': '14.170162',
#      'Name': 'Doksany',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'UKRUA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.9'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.696671',
#      'Lon': '13.847692',
#      'Name': 'Krupka',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'ULOMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '6.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '13.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '39.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#      'Ix': 1,
#      'Lat': '50.585766',
#      'Lon': '13.673418',
#      'Name': 'Lom',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'ULTTA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.540897',
#      'Lon': '14.119409',
#      'Name': 'Litoměřice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'UMEDA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.427589',
#      'Lon': '13.130143',
#      'Name': 'Měděnec',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'UMOMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '16.8'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '3.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '29.5'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.2'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '4.0'}],
#      'Ix': 1,
#      'Lat': '50.510365',
#      'Lon': '13.645272',
#      'Name': 'Most',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'URVHA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '44.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.579834',
#      'Lon': '13.419506',
#      'Name': 'Rudolice v Horách',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'USNZA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '2.7'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.8'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '43.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.789444',
#      'Lon': '14.086799',
#      'Name': 'Sněžník',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'USTEA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '6.1'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '21.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '19.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '26.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '16.0'}],
#      'Ix': 1,
#      'Lat': '50.454155',
#      'Lon': '14.374163',
#      'Name': 'Štětí',
#      'Owner': 'MSTE'},
#     {'Classif': 'městská',
#      'Code': 'UTPMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '37.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#      'Ix': 1,
#      'Lat': '50.645279',
#      'Lon': '13.851250',
#      'Name': 'Teplice ',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'UTUSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '1.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '38.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '2.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '9.0'}],
#      'Ix': 1,
#      'Lat': '50.376587',
#      'Lon': '13.327622',
#      'Name': 'Tušimice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'průmyslová',
#      'Code': 'UUDIA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#      'Ix': 1,
#      'Lat': '50.662979',
#      'Lon': '14.031243',
#      'Name': 'Ústí n. L.-Prokopa Diviše',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'dopravní',
#      'Code': 'UULDA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '359'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '12.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#      'Ix': 0,
#      'Lat': '50.683125',
#      'Lon': '13.997873',
#      'Name': 'Ústí n.L.-Všebořická (hot spot)',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'UULKA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.8'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '42.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#      'Ix': 1,
#      'Lat': '50.683525',
#      'Lon': '14.041195',
#      'Name': 'Ústí n.L.-Kočkov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'UULMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '10.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.1'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.661095',
#      'Lon': '14.043063',
#      'Name': 'Ústí n.L.-město',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'L',
#    'Name': 'Liberecký',
#    'Stations': [{'Classif': 'městská',
#      'Code': 'LCLMA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '6.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '6.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '50.698044',
#      'Lon': '14.537345',
#      'Name': 'Česká Lípa',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'LFRTA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '41.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.940651',
#      'Lon': '15.069817',
#      'Name': 'Frýdlant',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'LLILA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '21.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '17.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '31.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '7.0'}],
#      'Ix': 1,
#      'Lat': '50.755100',
#      'Lon': '15.069967',
#      'Name': 'Liberec Rochlice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'LSOUA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '53.5'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.789646',
#      'Lon': '15.319683',
#      'Name': 'Souš',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'H',
#    'Name': 'Královéhradecký',
#    'Stations': [{'Classif': 'dopravní',
#      'Code': 'HHKBA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '50.195362',
#      'Lon': '15.846376',
#      'Name': 'Hradec Králové-Brněnská',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'HHKOK',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.177631',
#      'Lon': '15.838390',
#      'Name': 'Hradec Králové-observatoř',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'HHKSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '50.211700',
#      'Lon': '15.814149',
#      'Name': 'Hr.Král.-Sukovy sady',
#      'Owner': 'ZÚ Ústí nL'},
#     {'Classif': 'venkovská',
#      'Code': 'HKRYA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.660439',
#      'Lon': '15.850090',
#      'Name': 'Krkonoše-Rýchory',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'HPLOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 0,
#      'Lat': '50.350563',
#      'Lon': '16.322727',
#      'Name': 'Polom',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'HTRTA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 0,
#      'Lat': '50.565880',
#      'Lon': '15.903927',
#      'Name': 'Trutnov - Tkalcovská',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'E',
#    'Name': 'Pardubický',
#    'Stations': [{'Classif': 'městská',
#      'Code': 'EMTPA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '49.758995',
#      'Lon': '16.666721',
#      'Name': 'Moravská Třebová - Piaristická.',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'EPAOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '50.042198',
#      'Lon': '15.739414',
#      'Name': 'Pardubice-Rosice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'EPAUA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '50.024036',
#      'Lon': '15.763549',
#      'Name': 'Pardubice Dukla',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'ESVRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.735085',
#      'Lon': '16.034197',
#      'Name': 'Svratouch',
#      'Owner': 'ČHMÚ'}]},
#   {'Code': 'J',
#    'Name': 'Vysočina',
#    'Stations': [{'Classif': 'městská',
#      'Code': 'JJIHA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '245'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '13.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '41.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '9.0'}],
#      'Ix': 1,
#      'Lat': '49.401596',
#      'Lon': '15.610246',
#      'Name': 'Jihlava',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'JJIZA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '34.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '5.2'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '6.0'}],
#      'Ix': 2,
#      'Lat': '49.392445',
#      'Lon': '15.591278',
#      'Name': 'Jihlava-Znojemská',
#      'Owner': 'ZÚ-Ostrava'},
#     {'Classif': 'venkovská',
#      'Code': 'JKMYA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '25.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.159153',
#      'Lon': '15.439048',
#      'Name': 'Kostelní Myslová',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'JKOSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.4'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '4.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '225'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '7.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '49.1'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '3.0'}],
#      'Ix': 1,
#      'Lat': '49.573395',
#      'Lon': '15.080278',
#      'Name': 'Košetice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'JTREA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '10.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '4.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '49.223438',
#      'Lon': '15.865778',
#      'Name': 'Třebíč',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'JZNZA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '11.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '3.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '10.0'}],
#      'Ix': 1,
#      'Lat': '49.564556',
#      'Lon': '15.941000',
#      'Name': 'Ždár nad Sázavou',
#      'Owner': 'ZÚ-Ostrava'}]},
#   {'Code': 'B',
#    'Name': 'Jihomoravský',
#    'Stations': [{'Classif': 'městská',
#      'Code': 'BBDNA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '21.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '10.0'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '7.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '13.0'}],
#      'Ix': 2,
#      'Lat': '49.202724',
#      'Lon': '16.616287',
#      'Name': 'Brno - Dětská nemocnice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'BBMAA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.4'},
# ...
#     {'Classif': 'městská',
#      'Code': 'ZZZSA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '7.5'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '22.5'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '9.8'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '20.5'}],
#      'Ix': 2,
#      'Lat': '49.228474',
#      'Lon': '17.675083',
#      'Name': 'Zlín - ZŠ Kvítkova',
#      'Owner': 'MZLl'}]},
#   {'Code': 'T',
#    'Name': 'Moravskoslezský',
#    'Stations': [{'Classif': 'venkovská',
#      'Code': 'TBKRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '13.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '35.3'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.502609',
#      'Lon': '18.538561',
#      'Name': 'Bílý Kříž',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'TCERA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '6.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '46.7'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.777142',
#      'Lon': '17.541946',
#      'Name': 'Červená hora',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'TCTNA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '8.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '34.2'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '58.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '21.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '61.0'}],
#      'Ix': 3,
#      'Lat': '49.748959',
#      'Lon': '18.609726',
#      'Name': 'Český Těšín',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'TFMIA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '32.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '21.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '13.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '41.0'}],
#      'Ix': 2,
#      'Lat': '49.671791',
#      'Lon': '18.351070',
#      'Name': 'Frýdek-Místek',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'THAOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '35.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '19.9'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '49.771526',
#      'Lon': '18.443193',
#      'Name': 'Havířov',
#      'Owner': 'ZÚ, SMHa'},
#     {'Classif': 'městská',
#      'Code': 'THARA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '38.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '21.5'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '50.0'}],
#      'Ix': 2,
#      'Lat': '49.790977',
#      'Lon': '18.406836',
#      'Name': 'Havířov',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'dopravní',
#      'Code': 'TKAOK',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '43.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '42.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '24.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '38.0'}],
#      'Ix': 3,
#      'Lat': '49.858891',
#      'Lon': '18.557777',
#      'Name': 'Karviná-ZÚ',
#      'Owner': 'ZÚ-Ostrava'},
#     {'Classif': 'městská',
#      'Code': 'TKARA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '8.5'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '33.5'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '49.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '13.4'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '26.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '49.0'}],
#      'Ix': 3,
#      'Lat': '49.863796',
#      'Lon': '18.551453',
#      'Name': 'Karviná',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'TNSVA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '49.653072',
#      'Lon': '18.431831',
#      'Name': 'Nošovice',
#      'Owner': 'ONOS'},
#     {'Classif': 'dopravní',
#      'Code': 'TOCBA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 0},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 0},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '49.839848',
#      'Lon': '18.289976',
#      'Name': 'Ostrava-Českobratrská (hot spot)',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'TOFFA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '4.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '23.7'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '31.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '21.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '14.2'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '49.839188',
#      'Lon': '18.263689',
#      'Name': 'Ostrava-Fifejdy',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'průmyslová',
#      'Code': 'TOHBA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.6'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '25.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '469'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '28.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '13.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '49.778610',
#      'Lon': '18.278807',
#      'Name': 'Ostrava-Hrabová',
#      'Owner': 'ZÚ, MSK'},
#     {'Classif': 'průmyslová',
#      'Code': 'TOKUA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.6'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '19.1'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '533'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 1, 'Val': '20.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '14.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 1,
#      'Lat': '49.809692',
#      'Lon': '18.292500',
#      'Name': 'Ostrava-Kunčičky',
#      'Owner': 'ZÚ, MSK'},
#     {'Classif': 'průmyslová',
#      'Code': 'TOMHK',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.6'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '26.6'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '303'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '25.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '22.5'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '10.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '49.824860',
#      'Lon': '18.263655',
#      'Name': 'Ostrava-Mariánské Hory',
#      'Owner': 'ZÚ, SMOva'},
#     {'Classif': 'dopravní',
#      'Code': 'TOPDA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '18.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '31.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '13.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '49.835472',
#      'Lon': '18.165222',
#      'Name': 'Ostrava-Poruba, DD',
#      'Owner': 'ZÚ, SMOva'},
#     {'Classif': 'předměstská',
#      'Code': 'TOPOA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '23.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': -1},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -1},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': -1,
#      'Lat': '49.825294',
#      'Lon': '18.159275',
#      'Name': 'Ostrava-Poruba/ČHMÚ',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'průmyslová',
#      'Code': 'TOPRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '4.0'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '22.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '33.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '18.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '33.0'}],
#      'Ix': 2,
#      'Lat': '49.856258',
#      'Lon': '18.269741',
#      'Name': 'Ostrava-Přívoz',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'průmyslová',
#      'Code': 'TOREK',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '11.2'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '29.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '435'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 0},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '15.0'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': ''},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': ''}],
#      'Ix': 0,
#      'Lat': '49.807056',
#      'Lon': '18.339140',
#      'Name': 'Ostrava-Radvanice ZÚ',
#      'Owner': 'ZÚ, SMOva'},
#     {'Classif': 'předměstská',
#      'Code': 'TOROK',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.6'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '39.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '26.3'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '22.4'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 2,
#      'Lat': '49.818558',
#      'Lon': '18.340389',
#      'Name': 'Ostrava-Radvanice OZO',
#      'Owner': 'ZÚ, SMOva'},
#     {'Classif': 'městská',
#      'Code': 'TOVKA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '17.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '43.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '22.9'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '12.0'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '35.0'}],
#      'Ix': 3,
#      'Lat': '49.944988',
#      'Lon': '17.909531',
#      'Name': 'Opava-Kateřinky',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'TOZRA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '31.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '16.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '44.0'}],
#      'Ix': 2,
#      'Lat': '49.796040',
#      'Lon': '18.247181',
#      'Name': 'Ostrava-Zábřeh',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'městská',
#      'Code': 'TRYCA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '5.6'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '29.3'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 2, 'Val': '40.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '20.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '40.0'}],
#      'Ix': 2,
#      'Lat': '49.871670',
#      'Lon': '18.377254',
#      'Name': 'Rychvald',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'TSTDA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '1.3'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 1, 'Val': '16.5'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 1, 'Val': '302'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '42.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '23.5'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '21.3'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '36.0'}],
#      'Ix': 3,
#      'Lat': '49.720936',
#      'Lon': '18.089306',
#      'Name': 'Studénka',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'předměstská',
#      'Code': 'TTRKA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '39.0'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '59.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '21.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '57.0'}],
#      'Ix': 3,
#      'Lat': '49.672379',
#      'Lon': '18.643038',
#      'Name': 'Třinec-Kanada',
#      'Owner': 'MTŘ'},
#     {'Classif': 'městská',
#      'Code': 'TTROA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': -1},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '50.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -2, 'Val': '15.8'},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '17.8'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '44.0'}],
#      'Ix': 3,
#      'Lat': '49.668114',
#      'Lon': '18.677799',
#      'Name': 'Třinec-Kosmos',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'venkovská',
#      'Code': 'TVERA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '8.0'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '25.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '49.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '22.6'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -2, 'Val': '42.0'}],
#      'Ix': 3,
#      'Lat': '49.924679',
#      'Lon': '18.422873',
#      'Name': 'Věřňovice',
#      'Owner': 'ČHMÚ'},
#     {'Classif': 'průmyslová',
#      'Code': 'TVRTA',
#      'Components': [{'Code': 'SO2', 'Int': '1h', 'Ix': 1, 'Val': '14.6'},
#       {'Code': 'NO2', 'Int': '1h', 'Ix': 2, 'Val': '30.4'},
#       {'Code': 'CO', 'Int': '8h', 'Ix': 2, 'Val': '1 039'},
#       {'Code': 'PM10', 'Int': '1h', 'Ix': 3, 'Val': '44.0'},
#       {'Code': 'O3', 'Int': '1h', 'Ix': -1},
#       {'Code': 'PM10', 'Int': '24h', 'Ix': -2, 'Val': '18.7'},
#       {'Code': 'PM2_5', 'Int': '1h', 'Ix': -1}],
#      'Ix': 3,
#      'Lat': '49.769806',
#      'Lon': '18.318472',
#      'Name': 'Vratimov',
#      'Owner': 'ZÚ, MSK'}]}]}

# %%
stations = []
for r in czech[0]['Regions']:
    for s in r['Stations']:
        row = {'Station': s['Name'], 'Region': r['Name']}
        for c in s.get('Components', []):
            if 'Val' in c:
                row[c['Code']] = c['Val']
        stations.append(row)
air_pollution = pd.DataFrame.from_records(stations, index=['Region', 'Station'])
air_pollution.head()
# Out:
#                                      CO   NO2    O3  PM10 PM2_5  SO2
# Region Station
# Praha  Střed Prahy                  NaN   NaN   NaN   NaN   NaN  NaN
#        Praha 8-Karlín               NaN   NaN   NaN  12.0   NaN  NaN
#        Praha 2-Legerova (hot spot)  356  67.0   NaN   6.1   7.0  NaN
#        Praha 1-n. Republiky         NaN  40.2   NaN   9.6   NaN  NaN
#        Praha 2-Riegrovy sady        NaN  24.7  36.9   5.9  32.0  1.3

# %% [markdown]
# ### Titanic data

# %%
titanic = pd.read_excel('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls')
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Bonus: hell with excel
#
# Data from [Czech statistical office](https://www.czso.cz/csu/gender/2-gender_obyvatelstvo)
#
# First marriages: by age of groom and bride
#
# In order to make these table look more like tidy data:
#
# 1. Exclude empty rows in the beginning of the table
# 2. Make nice header
# 3. Exclude Czech names in header and index column

# %%
link = 'https://www.czso.cz/documents/10180/32853391/300002161106.xlsx/6bcf2981-2bf8-40c5-aac6-cefbf3034783?version=1.1'
pd.read_excel(link)
# Out:
#                                          OBYVATELSTVO  \
# 0            1 - 6. První sňatky podle věku snoubenců
# 1            First marriages: by age of groom and ...
# 2                                         Pramen: ČSÚ
# 3                                            Věk\nAge
# 4                                                 NaN
# 5                                                 NaN
# 6                                      Celkem\n Total
# 7                                             16 - 19
# 8                                             20 - 24
# 9                                             25 - 29
# 10                                            30 - 34
# 11                                            35 - 39
# 12                                            40 - 44
# 13                                            45 - 49
# 14                                            50 - 54
# 15                                                55+
# 16                                                NaN
# 17                                     Celkem\n Total
# 18                                            16 - 19
# 19                                            20 - 24
# 20                                            25 - 29
# 21                                            30 - 34
# 22                                            35 - 39
# 23                                            40 - 44
# 24                                            45 - 49
# 25                                            50 - 54
# 26                                                55+
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
#
#                                            Unnamed: 1      Unnamed: 2  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                1993             NaN
# 4                                       ženich\nGroom  nevěsta\nBride
# 5                                                 NaN             NaN
# 6                                               51319           51450
# 7                                                5809           20105
# 8                                               28661           24770
# 9                                               11937            4734
# 10                                               2913            1058
# 11                                               1123             394
# 12                                                454             179
# 13                                                200             104
# 14                                                103              33
# 15                                                119              73
# 16  struktura v %                               St...             NaN
# 17                                                100             100
# 18                                            11.3194         39.0768
# 19                                            55.8487         48.1438
# 20                                            23.2604         9.20117
# 21                                            5.67626         2.05637
# 22                                            2.18827        0.765792
# 23                                           0.884663        0.347911
# 24                                           0.389719        0.202138
# 25                                           0.200705       0.0641399
# 26                                           0.231883        0.141885
# 27                                                NaN             NaN
# 28                                                NaN             NaN
# 29                                                NaN             NaN
# ..                                                ...             ...
# 41                                                NaN             NaN
# 42                                                NaN             NaN
# 43                                                NaN             NaN
# 44                                                NaN             NaN
# 45                                                NaN             NaN
# 46                                                NaN             NaN
# 47                                                NaN             NaN
# 48                                                NaN             NaN
# 49                                                NaN             NaN
# 50                                                NaN             NaN
# 51                                                NaN             NaN
# 52                                                NaN             NaN
# 53                                                NaN             NaN
# 54                                                NaN             NaN
# 55                                                NaN             NaN
# 56                                                NaN             NaN
# 57                                                NaN             NaN
# 58                                                NaN             NaN
# 59                                                NaN             NaN
# 60                                                NaN             NaN
# 61                                                NaN             NaN
# 62                                                NaN             NaN
# 63                                                NaN             NaN
# 64                                                NaN             NaN
# 65                                                NaN             NaN
# 66                                                NaN             NaN
# 67                                                NaN             NaN
# 68                                                NaN             NaN
# 69                                                NaN             NaN
# 70                                                NaN             NaN
#
#        Unnamed: 3      Unnamed: 4     Unnamed: 5      Unnamed: 6  \
# 0             NaN             NaN            NaN             NaN
# 1             NaN             NaN            NaN             NaN
# 2             NaN             NaN            NaN             NaN
# 3            2000             NaN           2003             NaN
# 4   ženich\nGroom  nevěsta\nBride  ženich\nGroom  nevěsta\nBride
# 5             NaN             NaN            NaN             NaN
# 6           41360           41528          36016           36371
# 7             701            3008            273            1503
# 8           14273           22765           7307           14212
# 9           18652           13093          18537           16724
# 10           5061            1822           6951            3025
# 11           1561             458           1786             533
# 12            530             162            564             171
# 13            280              94            281              90
# 14            144              53            158              66
# 15            158              73            159              47
# 16            NaN             NaN            NaN             NaN
# 17            100             100            100             100
# 18        1.69487         7.24331       0.757996         4.13241
# 19        34.5092         54.8184        20.2882         39.0751
# 20        45.0967         31.5281        51.4688         45.9817
# 21        12.2365          4.3874        19.2998         8.31707
# 22        3.77418         1.10287        4.95891         1.46545
# 23        1.28143        0.390098        1.56597        0.470155
# 24       0.676983        0.226353       0.780209         0.24745
# 25       0.348162        0.127625       0.438694        0.181463
# 26       0.382012        0.175785        0.44147        0.129224
# 27            NaN             NaN            NaN             NaN
# 28            NaN             NaN            NaN             NaN
# 29            NaN             NaN            NaN             NaN
# ..            ...             ...            ...             ...
# 41            NaN             NaN            NaN             NaN
# 42            NaN             NaN            NaN             NaN
# 43            NaN             NaN            NaN             NaN
# 44            NaN             NaN            NaN             NaN
# 45            NaN             NaN            NaN             NaN
# 46            NaN             NaN            NaN             NaN
# 47            NaN             NaN            NaN             NaN
# 48            NaN             NaN            NaN             NaN
# 49            NaN             NaN            NaN             NaN
# 50            NaN             NaN            NaN             NaN
# 51            NaN             NaN            NaN             NaN
# 52            NaN             NaN            NaN             NaN
# 53            NaN             NaN            NaN             NaN
# 54            NaN             NaN            NaN             NaN
# 55            NaN             NaN            NaN             NaN
# 56            NaN             NaN            NaN             NaN
# 57            NaN             NaN            NaN             NaN
# 58            NaN             NaN            NaN             NaN
# 59            NaN             NaN            NaN             NaN
# 60            NaN             NaN            NaN             NaN
# 61            NaN             NaN            NaN             NaN
# 62            NaN             NaN            NaN             NaN
# 63            NaN             NaN            NaN             NaN
# 64            NaN             NaN            NaN             NaN
# 65            NaN             NaN            NaN             NaN
# 66            NaN             NaN            NaN             NaN
# 67            NaN             NaN            NaN             NaN
# 68            NaN             NaN            NaN             NaN
# 69            NaN             NaN            NaN             NaN
# 70            NaN             NaN            NaN             NaN
#
#        Unnamed: 7      Unnamed: 8     Unnamed: 9     ...         Unnamed: 22  \
# 0             NaN             NaN            NaN     ...                 NaN
# 1             NaN             NaN            NaN     ...                 NaN
# 2             NaN             NaN            NaN     ...                 NaN
# 3            2004             NaN           2005     ...                 NaN
# 4   ženich\nGroom  nevěsta\nBride  ženich\nGroom     ...      nevěsta\nBride
# 5             NaN             NaN            NaN     ...                 NaN
# 6           37940           38147          38347     ...               33443
# 7             264            1390            220     ...                 474
# 8            6401           12892           5342     ...                6795
# 9           19220           18799          19128     ...               15376
# 10           8715            4037          10103     ...                8204
# 11           2054             611           2146     ...                2013
# 12            656             203            740     ...                 357
# 13            294              98            296     ...                 116
# 14            159              59            201     ...                  51
# 15            177              58            171     ...                  57
# 16            NaN             NaN            NaN     ...                 NaN
# 17            100             100            100     ...                 100
# 18       0.695836          3.6438       0.573709     ...             1.41734
# 19        16.8714         33.7956        13.9307     ...             20.3182
# 20        50.6589         49.2804        49.8813     ...             45.9767
# 21        22.9705         10.5827        26.3463     ...             24.5313
# 22        5.41381          1.6017        5.59627     ...              6.0192
# 23        1.72905        0.532152        1.92975     ...             1.06749
# 24       0.774908        0.256901       0.771899     ...            0.346859
# 25       0.419083        0.154665       0.524161     ...            0.152498
# 26       0.466526        0.152043       0.445928     ...            0.170439
# 27            NaN             NaN            NaN     ...                 NaN
# 28            NaN             NaN            NaN     ...                 NaN
# 29            NaN             NaN            NaN     ...                 NaN
# ..            ...             ...            ...     ...                 ...
# 41            NaN             NaN            NaN     ...                 NaN
# 42            NaN             NaN            NaN     ...                 NaN
# 43            NaN             NaN            NaN     ...                 NaN
# 44            NaN             NaN            NaN     ...                 NaN
# 45            NaN             NaN            NaN     ...                 NaN
# 46            NaN             NaN            NaN     ...                 NaN
# 47            NaN             NaN            NaN     ...                 NaN
# 48            NaN             NaN            NaN     ...                 NaN
# 49            NaN             NaN            NaN     ...                 NaN
# 50            NaN             NaN            NaN     ...                 NaN
# 51            NaN             NaN            NaN     ...                 NaN
# 52            NaN             NaN            NaN     ...                 NaN
# 53            NaN             NaN            NaN     ...                 NaN
# 54            NaN             NaN            NaN     ...                 NaN
# 55            NaN             NaN            NaN     ...                 NaN
# 56            NaN             NaN            NaN     ...                 NaN
# 57            NaN             NaN            NaN     ...                 NaN
# 58            NaN             NaN            NaN     ...                 NaN
# 59            NaN             NaN            NaN     ...                 NaN
# 60            NaN             NaN            NaN     ...                 NaN
# 61            NaN             NaN            NaN     ...                 NaN
# 62            NaN             NaN            NaN     ...                 NaN
# 63            NaN             NaN            NaN     ...                 NaN
# 64            NaN             NaN            NaN     ...                 NaN
# 65            NaN             NaN            NaN     ...                 NaN
# 66            NaN             NaN            NaN     ...                 NaN
# 67            NaN             NaN            NaN     ...                 NaN
# 68            NaN             NaN            NaN     ...                 NaN
# 69            NaN             NaN            NaN     ...                 NaN
# 70            NaN             NaN            NaN     ...                 NaN
#
#       Unnamed: 23     Unnamed: 24    Unnamed: 25     Unnamed: 26  \
# 0             NaN             NaN            NaN             NaN
# 1             NaN             NaN            NaN             NaN
# 2             NaN             NaN            NaN             NaN
# 3            2013             NaN           2014             NaN
# 4   ženich\nGroom  nevěsta\nBride  ženich\nGroom  nevěsta\nBride
# 5             NaN             NaN            NaN             NaN
# 6           32743           33029          34691           35155
# 7              91             430             73             383
# 8            2567            5961           2562            6026
# 9           11257           15045          11644           15778
# 10          11480            8282          12104            9075
# 11           5233            2589           5869            3001
# 12           1298             448           1567             606
# 13            403             122            459             132
# 14            180              65            199              75
# 15            234              87            214              79
# 16            NaN             NaN            NaN             NaN
# 17            100             100            100             100
# 18       0.277922         1.30189       0.210429         1.08946
# 19        7.83984         18.0478         7.3852         17.1412
# 20        34.3799         45.5509        33.5649         44.8812
# 21        35.0609         25.0749        34.8909         25.8143
# 22         15.982         7.83857        16.9179         8.53648
# 23        3.96421         1.35638        4.51702         1.72379
# 24         1.2308        0.369372        1.32311         0.37548
# 25       0.549736        0.196797       0.573636        0.213341
# 26       0.714657        0.263405       0.616875        0.224719
# 27            NaN             NaN            NaN             NaN
# 28            NaN             NaN            NaN             NaN
# 29            NaN             NaN            NaN             NaN
# ..            ...             ...            ...             ...
# 41            NaN             NaN            NaN             NaN
# 42            NaN             NaN            NaN             NaN
# 43            NaN             NaN            NaN             NaN
# 44            NaN             NaN            NaN             NaN
# 45            NaN             NaN            NaN             NaN
# 46            NaN             NaN            NaN             NaN
# 47            NaN             NaN            NaN             NaN
# 48            NaN             NaN            NaN             NaN
# 49            NaN             NaN            NaN             NaN
# 50            NaN             NaN            NaN             NaN
# 51            NaN             NaN            NaN             NaN
# 52            NaN             NaN            NaN             NaN
# 53            NaN             NaN            NaN             NaN
# 54            NaN             NaN            NaN             NaN
# 55            NaN             NaN            NaN             NaN
# 56            NaN             NaN            NaN             NaN
# 57            NaN             NaN            NaN             NaN
# 58            NaN             NaN            NaN             NaN
# 59            NaN             NaN            NaN             NaN
# 60            NaN             NaN            NaN             NaN
# 61            NaN             NaN            NaN             NaN
# 62            NaN             NaN            NaN             NaN
# 63            NaN             NaN            NaN             NaN
# 64            NaN             NaN            NaN             NaN
# 65            NaN             NaN            NaN             NaN
# 66            NaN             NaN            NaN             NaN
# 67            NaN             NaN            NaN             NaN
# 68            NaN             NaN            NaN             NaN
# 69            NaN             NaN            NaN             NaN
# 70            NaN             NaN            NaN             NaN
#
#       Unnamed: 27      POPULATION Unnamed: 29 Unnamed: 30 Unnamed: 31
# 0             NaN             NaN         NaN         NaN         NaN
# 1             NaN             NaN         NaN         NaN         NaN
# 2             NaN    Source: CZSO         NaN         NaN         NaN
# 3            2015             NaN         NaN         NaN         NaN
# 4   ženich\nGroom  nevěsta\nBride         NaN         NaN         NaN
# 5             NaN             NaN         NaN         NaN         NaN
# 6           36884           37021         NaN         NaN         NaN
# 7              74             379         NaN         NaN         NaN
# 8            2847            6370         NaN         NaN         NaN
# 9           12150           16395         NaN         NaN         NaN
# 10          12404            9401         NaN         NaN         NaN
# 11           6365            3345         NaN         NaN         NaN
# 12           1984             825         NaN         NaN         NaN
# 13            586             167         NaN         NaN         NaN
# 14            250              78         NaN         NaN         NaN
# 15            224              61         NaN         NaN         NaN
# 16            NaN             NaN         NaN         NaN         NaN
# 17            100             100         NaN         NaN         NaN
# 18       0.200629         1.02374         NaN         NaN         NaN
# 19        7.71879         17.2065         NaN         NaN         NaN
# 20        32.9411         44.2857         NaN         NaN         NaN
# 21        33.6298         25.3937         NaN         NaN         NaN
# 22        17.2568         9.03541         NaN         NaN         NaN
# 23        5.37903         2.22846         NaN         NaN         NaN
# 24        1.58876        0.451095         NaN         NaN         NaN
# 25       0.677801        0.210691         NaN         NaN         NaN
# 26       0.607309        0.164771         NaN         NaN         NaN
# 27            NaN             NaN         NaN         NaN         NaN
# 28            NaN             NaN         NaN         NaN         NaN
# 29            NaN             NaN         NaN         NaN         NaN
# ..            ...             ...         ...         ...         ...
# 41            NaN             NaN         NaN         NaN         NaN
# 42            NaN             NaN         NaN         NaN         NaN
# 43            NaN             NaN         NaN         NaN         NaN
# 44            NaN             NaN         NaN         NaN         NaN
# 45            NaN             NaN         NaN         NaN         NaN
# 46            NaN             NaN         NaN         NaN         NaN
# 47            NaN             NaN         NaN         NaN         NaN
# 48            NaN             NaN         NaN         NaN         NaN
# 49            NaN             NaN         NaN         NaN         NaN
# 50            NaN             NaN         NaN         NaN         NaN
# 51            NaN             NaN         NaN         NaN         NaN
# 52            NaN             NaN         NaN         NaN         NaN
# 53            NaN             NaN         NaN         NaN         NaN
# 54            NaN             NaN         NaN         NaN         NaN
# 55            NaN             NaN         NaN         NaN         NaN
# 56            NaN             NaN         NaN         NaN         NaN
# 57            NaN             NaN         NaN         NaN         NaN
# 58            NaN             NaN         NaN         NaN         NaN
# 59            NaN             NaN         NaN         NaN         NaN
# 60            NaN             NaN         NaN         NaN         NaN
# 61            NaN             NaN         NaN         NaN         NaN
# 62            NaN             NaN         NaN         NaN         NaN
# 63            NaN             NaN         NaN         NaN         NaN
# 64            NaN             NaN         NaN         NaN         NaN
# 65            NaN             NaN         NaN         NaN         NaN
# 66            NaN             NaN         NaN         NaN         NaN
# 67            NaN             NaN         NaN         NaN         NaN
# 68            NaN             NaN         NaN         NaN         NaN
# 69            NaN             NaN         NaN         NaN         NaN
# 70            NaN             NaN         NaN         NaN         0.0
#
# [71 rows x 32 columns]

# %%
pd.read_excel(link, header = 5)
# Out:
#                                                     ženich\nGroom  \
# NaN                                                           NaN
# Celkem\n Total                                              51319
# 16 - 19                                                      5809
# 20 - 24                                                     28661
# 25 - 29                                                     11937
# 30 - 34                                                      2913
# 35 - 39                                                      1123
# 40 - 44                                                       454
# 45 - 49                                                       200
# 50 - 54                                                       103
# 55+                                                           119
# NaN             struktura v %                               St...
# Celkem\n Total                                                100
# 16 - 19                                                   11.3194
# 20 - 24                                                   55.8487
# 25 - 29                                                   23.2604
# 30 - 34                                                   5.67626
# 35 - 39                                                   2.18827
# 40 - 44                                                  0.884663
# 45 - 49                                                  0.389719
# 50 - 54                                                  0.200705
# 55+                                                      0.231883
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# ...                                                           ...
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
#
#                 nevěsta\nBride  ženich\nGroom.1  nevěsta\nBride.1  \
# NaN                        NaN              NaN               NaN
# Celkem\n Total    51450.000000     41360.000000      41528.000000
# 16 - 19           20105.000000       701.000000       3008.000000
# 20 - 24           24770.000000     14273.000000      22765.000000
# 25 - 29            4734.000000     18652.000000      13093.000000
# 30 - 34            1058.000000      5061.000000       1822.000000
# 35 - 39             394.000000      1561.000000        458.000000
# 40 - 44             179.000000       530.000000        162.000000
# 45 - 49             104.000000       280.000000         94.000000
# 50 - 54              33.000000       144.000000         53.000000
# 55+                  73.000000       158.000000         73.000000
# NaN                        NaN              NaN               NaN
# Celkem\n Total      100.000000       100.000000        100.000000
# 16 - 19              39.076774         1.694874          7.243306
# 20 - 24              48.143829        34.509188         54.818436
# 25 - 29               9.201166        45.096712         31.528126
# 30 - 34               2.056365        12.236460          4.387401
# 35 - 39               0.765792         3.774178          1.102870
# 40 - 44               0.347911         1.281431          0.390098
# 45 - 49               0.202138         0.676983          0.226353
# 50 - 54               0.064140         0.348162          0.127625
# 55+                   0.141885         0.382012          0.175785
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# ...                        ...              ...               ...
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
# NaN                        NaN              NaN               NaN
#
#                 ženich\nGroom.2  nevěsta\nBride.2  ženich\nGroom.3  \
# NaN                         NaN               NaN              NaN
# Celkem\n Total     36016.000000      36371.000000     37940.000000
# 16 - 19              273.000000       1503.000000       264.000000
# 20 - 24             7307.000000      14212.000000      6401.000000
# 25 - 29            18537.000000      16724.000000     19220.000000
# 30 - 34             6951.000000       3025.000000      8715.000000
# 35 - 39             1786.000000        533.000000      2054.000000
# 40 - 44              564.000000        171.000000       656.000000
# 45 - 49              281.000000         90.000000       294.000000
# 50 - 54              158.000000         66.000000       159.000000
# 55+                  159.000000         47.000000       177.000000
# NaN                         NaN               NaN              NaN
# Celkem\n Total       100.000000        100.000000       100.000000
# 16 - 19                0.757996          4.132413         0.695836
# 20 - 24               20.288205         39.075087        16.871376
# 25 - 29               51.468792         45.981689        50.658935
# 30 - 34               19.299756          8.317066        22.970480
# 35 - 39                4.958907          1.465453         5.413811
# 40 - 44                1.565971          0.470155         1.729046
# 45 - 49                0.780209          0.247450         0.774908
# 50 - 54                0.438694          0.181463         0.419083
# 55+                    0.441470          0.129224         0.466526
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# ...                         ...               ...              ...
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
# NaN                         NaN               NaN              NaN
#
#                 nevěsta\nBride.3  ženich\nGroom.4  nevěsta\nBride.4  \
# NaN                          NaN              NaN               NaN
# Celkem\n Total      38147.000000     38347.000000      38605.000000
# 16 - 19              1390.000000       220.000000       1214.000000
# 20 - 24             12892.000000      5342.000000      11866.000000
# 25 - 29             18799.000000     19128.000000      19353.000000
# 30 - 34              4037.000000     10103.000000       5026.000000
# 35 - 39               611.000000      2146.000000        760.000000
# 40 - 44               203.000000       740.000000        177.000000
# 45 - 49                98.000000       296.000000         89.000000
# 50 - 54                59.000000       201.000000         58.000000
# 55+                    58.000000       171.000000         62.000000
# NaN                          NaN              NaN               NaN
# Celkem\n Total        100.000000       100.000000        100.000000
# 16 - 19                 3.643799         0.573709          3.144670
# 20 - 24                33.795580        13.930686         30.736951
# 25 - 29                49.280415        49.881347         50.130812
# 30 - 34                10.582746        26.346259         13.019039
# 35 - 39                 1.601699         5.596266          1.968657
# 40 - 44                 0.532152         1.929747          0.458490
# 45 - 49                 0.256901         0.771899          0.230540
# 50 - 54                 0.154665         0.524161          0.150240
# 55+                     0.152043         0.445928          0.160601
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# ...                          ...              ...               ...
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
# NaN                          NaN              NaN               NaN
#
#                    ...       nevěsta\nBride.10  ženich\nGroom.11  \
# NaN                ...                     NaN               NaN
# Celkem\n Total     ...            33443.000000      32743.000000
# 16 - 19            ...              474.000000         91.000000
# 20 - 24            ...             6795.000000       2567.000000
# 25 - 29            ...            15376.000000      11257.000000
# 30 - 34            ...             8204.000000      11480.000000
# 35 - 39            ...             2013.000000       5233.000000
# 40 - 44            ...              357.000000       1298.000000
# 45 - 49            ...              116.000000        403.000000
# 50 - 54            ...               51.000000        180.000000
# 55+                ...               57.000000        234.000000
# NaN                ...                     NaN               NaN
# Celkem\n Total     ...              100.000000        100.000000
# 16 - 19            ...                1.417337          0.277922
# 20 - 24            ...               20.318153          7.839844
# 25 - 29            ...               45.976737         34.379867
# 30 - 34            ...               24.531292         35.060929
# 35 - 39            ...                6.019197         15.982042
# 40 - 44            ...                1.067488          3.964206
# 45 - 49            ...                0.346859          1.230797
# 50 - 54            ...                0.152498          0.549736
# 55+                ...                0.170439          0.714657
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# ...                ...                     ...               ...
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
# NaN                ...                     NaN               NaN
#
#                 nevěsta\nBride.11  ženich\nGroom.12  nevěsta\nBride.12  \
# NaN                           NaN               NaN                NaN
# Celkem\n Total       33029.000000      34691.000000       35155.000000
# 16 - 19                430.000000         73.000000         383.000000
# 20 - 24               5961.000000       2562.000000        6026.000000
# 25 - 29              15045.000000      11644.000000       15778.000000
# 30 - 34               8282.000000      12104.000000        9075.000000
# 35 - 39               2589.000000       5869.000000        3001.000000
# 40 - 44                448.000000       1567.000000         606.000000
# 45 - 49                122.000000        459.000000         132.000000
# 50 - 54                 65.000000        199.000000          75.000000
# 55+                     87.000000        214.000000          79.000000
# NaN                           NaN               NaN                NaN
# Celkem\n Total         100.000000        100.000000         100.000000
# 16 - 19                  1.301886          0.210429           1.089461
# 20 - 24                 18.047776          7.385201          17.141232
# 25 - 29                 45.550880         33.564902          44.881240
# 30 - 34                 25.074934         34.890894          25.814251
# 35 - 39                  7.838566         16.917933           8.536481
# 40 - 44                  1.356384          4.517022           1.723795
# 45 - 49                  0.369372          1.323110           0.375480
# 50 - 54                  0.196797          0.573636           0.213341
# 55+                      0.263405          0.616875           0.224719
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# ...                           ...               ...                ...
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
# NaN                           NaN               NaN                NaN
#
#                 ženich\nGroom.13  nevěsta\nBride.13  Unnamed: 28  Unnamed: 29  \
# NaN                          NaN                NaN          NaN          NaN
# Celkem\n Total      36884.000000       37021.000000          NaN          NaN
# 16 - 19                74.000000         379.000000          NaN          NaN
# 20 - 24              2847.000000        6370.000000          NaN          NaN
# 25 - 29             12150.000000       16395.000000          NaN          NaN
# 30 - 34             12404.000000        9401.000000          NaN          NaN
# 35 - 39              6365.000000        3345.000000          NaN          NaN
# 40 - 44              1984.000000         825.000000          NaN          NaN
# 45 - 49               586.000000         167.000000          NaN          NaN
# 50 - 54               250.000000          78.000000          NaN          NaN
# 55+                   224.000000          61.000000          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# Celkem\n Total        100.000000         100.000000          NaN          NaN
# 16 - 19                 0.200629           1.023743          NaN          NaN
# 20 - 24                 7.718794          17.206450          NaN          NaN
# 25 - 29                32.941113          44.285676          NaN          NaN
# 30 - 34                33.629758          25.393695          NaN          NaN
# 35 - 39                17.256805           9.035412          NaN          NaN
# 40 - 44                 5.379026           2.228465          NaN          NaN
# 45 - 49                 1.588765           0.451095          NaN          NaN
# 50 - 54                 0.677801           0.210691          NaN          NaN
# 55+                     0.607309           0.164771          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# ...                          ...                ...          ...          ...
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
# NaN                          NaN                NaN          NaN          NaN
#
#                 Unnamed: 30
# NaN                     NaN
# Celkem\n Total          NaN
# 16 - 19                 NaN
# 20 - 24                 NaN
# 25 - 29                 NaN
# 30 - 34                 NaN
# 35 - 39                 NaN
# 40 - 44                 NaN
# 45 - 49                 NaN
# 50 - 54                 NaN
# 55+                     NaN
# NaN                     NaN
# Celkem\n Total          NaN
# 16 - 19                 NaN
# 20 - 24                 NaN
# 25 - 29                 NaN
# 30 - 34                 NaN
# 35 - 39                 NaN
# 40 - 44                 NaN
# 45 - 49                 NaN
# 50 - 54                 NaN
# 55+                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# ...                     ...
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     0.0
#
# [66 rows x 31 columns]

# %%
data = pd.read_excel(link, header = None, index_col = 0, skiprows = 4)
data
# Out:
#                                                                1   \
# 0
# Věk\nAge                                                     1993
# NaN                                                 ženich\nGroom
# NaN                                                           NaN
# Celkem\n Total                                              51319
# 16 - 19                                                      5809
# 20 - 24                                                     28661
# 25 - 29                                                     11937
# 30 - 34                                                      2913
# 35 - 39                                                      1123
# 40 - 44                                                       454
# 45 - 49                                                       200
# 50 - 54                                                       103
# 55+                                                           119
# NaN             struktura v %                               St...
# Celkem\n Total                                                100
# 16 - 19                                                   11.3194
# 20 - 24                                                   55.8487
# 25 - 29                                                   23.2604
# 30 - 34                                                   5.67626
# 35 - 39                                                   2.18827
# 40 - 44                                                  0.884663
# 45 - 49                                                  0.389719
# 50 - 54                                                  0.200705
# 55+                                                      0.231883
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# ...                                                           ...
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
#
#                             2              3               4              5   \
# 0
# Věk\nAge                   NaN           2000             NaN           2003
# NaN             nevěsta\nBride  ženich\nGroom  nevěsta\nBride  ženich\nGroom
# NaN                        NaN            NaN             NaN            NaN
# Celkem\n Total           51450          41360           41528          36016
# 16 - 19                  20105            701            3008            273
# 20 - 24                  24770          14273           22765           7307
# 25 - 29                   4734          18652           13093          18537
# 30 - 34                   1058           5061            1822           6951
# 35 - 39                    394           1561             458           1786
# 40 - 44                    179            530             162            564
# 45 - 49                    104            280              94            281
# 50 - 54                     33            144              53            158
# 55+                         73            158              73            159
# NaN                        NaN            NaN             NaN            NaN
# Celkem\n Total             100            100             100            100
# 16 - 19                39.0768        1.69487         7.24331       0.757996
# 20 - 24                48.1438        34.5092         54.8184        20.2882
# 25 - 29                9.20117        45.0967         31.5281        51.4688
# 30 - 34                2.05637        12.2365          4.3874        19.2998
# 35 - 39               0.765792        3.77418         1.10287        4.95891
# 40 - 44               0.347911        1.28143        0.390098        1.56597
# 45 - 49               0.202138       0.676983        0.226353       0.780209
# 50 - 54              0.0641399       0.348162        0.127625       0.438694
# 55+                   0.141885       0.382012        0.175785        0.44147
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# ...                        ...            ...             ...            ...
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
#
#                             6              7               8              9   \
# 0
# Věk\nAge                   NaN           2004             NaN           2005
# NaN             nevěsta\nBride  ženich\nGroom  nevěsta\nBride  ženich\nGroom
# NaN                        NaN            NaN             NaN            NaN
# Celkem\n Total           36371          37940           38147          38347
# 16 - 19                   1503            264            1390            220
# 20 - 24                  14212           6401           12892           5342
# 25 - 29                  16724          19220           18799          19128
# 30 - 34                   3025           8715            4037          10103
# 35 - 39                    533           2054             611           2146
# 40 - 44                    171            656             203            740
# 45 - 49                     90            294              98            296
# 50 - 54                     66            159              59            201
# 55+                         47            177              58            171
# NaN                        NaN            NaN             NaN            NaN
# Celkem\n Total             100            100             100            100
# 16 - 19                4.13241       0.695836          3.6438       0.573709
# 20 - 24                39.0751        16.8714         33.7956        13.9307
# 25 - 29                45.9817        50.6589         49.2804        49.8813
# 30 - 34                8.31707        22.9705         10.5827        26.3463
# 35 - 39                1.46545        5.41381          1.6017        5.59627
# 40 - 44               0.470155        1.72905        0.532152        1.92975
# 45 - 49                0.24745       0.774908        0.256901       0.771899
# 50 - 54               0.181463       0.419083        0.154665       0.524161
# 55+                   0.129224       0.466526        0.152043       0.445928
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# ...                        ...            ...             ...            ...
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
#
#                             10 ...               22             23  \
# 0                              ...
# Věk\nAge                   NaN ...              NaN           2013
# NaN             nevěsta\nBride ...   nevěsta\nBride  ženich\nGroom
# NaN                        NaN ...              NaN            NaN
# Celkem\n Total           38605 ...            33443          32743
# 16 - 19                   1214 ...              474             91
# 20 - 24                  11866 ...             6795           2567
# 25 - 29                  19353 ...            15376          11257
# 30 - 34                   5026 ...             8204          11480
# 35 - 39                    760 ...             2013           5233
# 40 - 44                    177 ...              357           1298
# 45 - 49                     89 ...              116            403
# 50 - 54                     58 ...               51            180
# 55+                         62 ...               57            234
# NaN                        NaN ...              NaN            NaN
# Celkem\n Total             100 ...              100            100
# 16 - 19                3.14467 ...          1.41734       0.277922
# 20 - 24                 30.737 ...          20.3182        7.83984
# 25 - 29                50.1308 ...          45.9767        34.3799
# 30 - 34                 13.019 ...          24.5313        35.0609
# 35 - 39                1.96866 ...           6.0192         15.982
# 40 - 44                0.45849 ...          1.06749        3.96421
# 45 - 49                0.23054 ...         0.346859         1.2308
# 50 - 54                0.15024 ...         0.152498       0.549736
# 55+                   0.160601 ...         0.170439       0.714657
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# ...                        ... ...              ...            ...
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
# NaN                        NaN ...              NaN            NaN
#
#                             24             25              26             27  \
# 0
# Věk\nAge                   NaN           2014             NaN           2015
# NaN             nevěsta\nBride  ženich\nGroom  nevěsta\nBride  ženich\nGroom
# NaN                        NaN            NaN             NaN            NaN
# Celkem\n Total           33029          34691           35155          36884
# 16 - 19                    430             73             383             74
# 20 - 24                   5961           2562            6026           2847
# 25 - 29                  15045          11644           15778          12150
# 30 - 34                   8282          12104            9075          12404
# 35 - 39                   2589           5869            3001           6365
# 40 - 44                    448           1567             606           1984
# 45 - 49                    122            459             132            586
# 50 - 54                     65            199              75            250
# 55+                         87            214              79            224
# NaN                        NaN            NaN             NaN            NaN
# Celkem\n Total             100            100             100            100
# 16 - 19                1.30189       0.210429         1.08946       0.200629
# 20 - 24                18.0478         7.3852         17.1412        7.71879
# 25 - 29                45.5509        33.5649         44.8812        32.9411
# 30 - 34                25.0749        34.8909         25.8143        33.6298
# 35 - 39                7.83857        16.9179         8.53648        17.2568
# 40 - 44                1.35638        4.51702         1.72379        5.37903
# 45 - 49               0.369372        1.32311         0.37548        1.58876
# 50 - 54               0.196797       0.573636        0.213341       0.677801
# 55+                   0.263405       0.616875        0.224719       0.607309
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# ...                        ...            ...             ...            ...
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
# NaN                        NaN            NaN             NaN            NaN
#
#                             28  29  30   31
# 0
# Věk\nAge                   NaN NaN NaN  NaN
# NaN             nevěsta\nBride NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# Celkem\n Total           37021 NaN NaN  NaN
# 16 - 19                    379 NaN NaN  NaN
# 20 - 24                   6370 NaN NaN  NaN
# 25 - 29                  16395 NaN NaN  NaN
# 30 - 34                   9401 NaN NaN  NaN
# 35 - 39                   3345 NaN NaN  NaN
# 40 - 44                    825 NaN NaN  NaN
# 45 - 49                    167 NaN NaN  NaN
# 50 - 54                     78 NaN NaN  NaN
# 55+                         61 NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# Celkem\n Total             100 NaN NaN  NaN
# 16 - 19                1.02374 NaN NaN  NaN
# 20 - 24                17.2065 NaN NaN  NaN
# 25 - 29                44.2857 NaN NaN  NaN
# 30 - 34                25.3937 NaN NaN  NaN
# 35 - 39                9.03541 NaN NaN  NaN
# 40 - 44                2.22846 NaN NaN  NaN
# 45 - 49               0.451095 NaN NaN  NaN
# 50 - 54               0.210691 NaN NaN  NaN
# 55+                   0.164771 NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# ...                        ...  ..  ..  ...
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  NaN
# NaN                        NaN NaN NaN  0.0
#
# [68 rows x 31 columns]

# %%
data.iloc[0]
# Out:
# 1     1993
# 2      NaN
# 3     2000
# 4      NaN
# 5     2003
# 6      NaN
# 7     2004
# 8      NaN
# 9     2005
# 10     NaN
# 11    2006
# 12     NaN
# 13    2007
# 14     NaN
# 15    2008
# 16     NaN
# 17    2009
# 18     NaN
# 19    2010
# 20     NaN
# 21    2011
# 22     NaN
# 23    2013
# 24     NaN
# 25    2014
# 26     NaN
# 27    2015
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# Name: Věk\nAge, dtype: object

# %%
data.iloc[5]
# Out:
# 1     28661
# 2     24770
# 3     14273
# 4     22765
# 5      7307
# 6     14212
# 7      6401
# 8     12892
# 9      5342
# 10    11866
# 11     4790
# 12    10989
# 13     4650
# 14    11009
# 15     4109
# 16     9735
# 17     3383
# 18     8066
# 19     2983
# 20     7376
# 21     2796
# 22     6795
# 23     2567
# 24     5961
# 25     2562
# 26     6026
# 27     2847
# 28     6370
# 29      NaN
# 30      NaN
# 31      NaN
# Name: 20 - 24, dtype: object

# %%
col1 = data.iloc[0].fillna(method = 'ffill')
col2 = data.iloc[1].str.split(pat='\n', n = 0).str.get(1)
columns = [col1, col2]

columns = list(zip(*columns))

# %%
data.columns = columns
data = data.drop(data.index[[0,1,2]])
data
# Out:
#                (1993, Groom) (1993, Bride) (2000, Groom) (2000, Bride)  \
# 0
# Celkem\n Total         51319         51450         41360         41528
# 16 - 19                 5809         20105           701          3008
# 20 - 24                28661         24770         14273         22765
# 25 - 29                11937          4734         18652         13093
# 30 - 34                 2913          1058          5061          1822
# 35 - 39                 1123           394          1561           458
# 40 - 44                  454           179           530           162
# 45 - 49                  200           104           280            94
# 50 - 54                  103            33           144            53
# 55+                      119            73           158            73
# Celkem\n Total           100           100           100           100
# 16 - 19              11.3194       39.0768       1.69487       7.24331
# 20 - 24              55.8487       48.1438       34.5092       54.8184
# 25 - 29              23.2604       9.20117       45.0967       31.5281
# 30 - 34              5.67626       2.05637       12.2365        4.3874
# 35 - 39              2.18827      0.765792       3.77418       1.10287
# 40 - 44             0.884663      0.347911       1.28143      0.390098
# 45 - 49             0.389719      0.202138      0.676983      0.226353
# 50 - 54             0.200705     0.0641399      0.348162      0.127625
# 55+                 0.231883      0.141885      0.382012      0.175785
#
#                (2003, Groom) (2003, Bride) (2004, Groom) (2004, Bride)  \
# 0
# Celkem\n Total         36016         36371         37940         38147
# 16 - 19                  273          1503           264          1390
# 20 - 24                 7307         14212          6401         12892
# 25 - 29                18537         16724         19220         18799
# 30 - 34                 6951          3025          8715          4037
# 35 - 39                 1786           533          2054           611
# 40 - 44                  564           171           656           203
# 45 - 49                  281            90           294            98
# 50 - 54                  158            66           159            59
# 55+                      159            47           177            58
# Celkem\n Total           100           100           100           100
# 16 - 19             0.757996       4.13241      0.695836        3.6438
# 20 - 24              20.2882       39.0751       16.8714       33.7956
# 25 - 29              51.4688       45.9817       50.6589       49.2804
# 30 - 34              19.2998       8.31707       22.9705       10.5827
# 35 - 39              4.95891       1.46545       5.41381        1.6017
# 40 - 44              1.56597      0.470155       1.72905      0.532152
# 45 - 49             0.780209       0.24745      0.774908      0.256901
# 50 - 54             0.438694      0.181463      0.419083      0.154665
# 55+                  0.44147      0.129224      0.466526      0.152043
#
#                (2005, Groom) (2005, Bride)     ...     (2011, Bride)  \
# 0                                              ...
# Celkem\n Total         38347         38605     ...             33443
# 16 - 19                  220          1214     ...               474
# 20 - 24                 5342         11866     ...              6795
# 25 - 29                19128         19353     ...             15376
# 30 - 34                10103          5026     ...              8204
# 35 - 39                 2146           760     ...              2013
# 40 - 44                  740           177     ...               357
# 45 - 49                  296            89     ...               116
# 50 - 54                  201            58     ...                51
# 55+                      171            62     ...                57
# Celkem\n Total           100           100     ...               100
# 16 - 19             0.573709       3.14467     ...           1.41734
# 20 - 24              13.9307        30.737     ...           20.3182
# 25 - 29              49.8813       50.1308     ...           45.9767
# 30 - 34              26.3463        13.019     ...           24.5313
# 35 - 39              5.59627       1.96866     ...            6.0192
# 40 - 44              1.92975       0.45849     ...           1.06749
# 45 - 49             0.771899       0.23054     ...          0.346859
# 50 - 54             0.524161       0.15024     ...          0.152498
# 55+                 0.445928      0.160601     ...          0.170439
#
#                (2013, Groom) (2013, Bride) (2014, Groom) (2014, Bride)  \
# 0
# Celkem\n Total         32743         33029         34691         35155
# 16 - 19                   91           430            73           383
# 20 - 24                 2567          5961          2562          6026
# 25 - 29                11257         15045         11644         15778
# 30 - 34                11480          8282         12104          9075
# 35 - 39                 5233          2589          5869          3001
# 40 - 44                 1298           448          1567           606
# 45 - 49                  403           122           459           132
# 50 - 54                  180            65           199            75
# 55+                      234            87           214            79
# Celkem\n Total           100           100           100           100
# 16 - 19             0.277922       1.30189      0.210429       1.08946
# 20 - 24              7.83984       18.0478        7.3852       17.1412
# 25 - 29              34.3799       45.5509       33.5649       44.8812
# 30 - 34              35.0609       25.0749       34.8909       25.8143
# 35 - 39               15.982       7.83857       16.9179       8.53648
# 40 - 44              3.96421       1.35638       4.51702       1.72379
# 45 - 49               1.2308      0.369372       1.32311       0.37548
# 50 - 54             0.549736      0.196797      0.573636      0.213341
# 55+                 0.714657      0.263405      0.616875      0.224719
#
#                (2015, Groom) (2015, Bride) (2015, nan) (2015, nan) (2015, nan)
# 0
# Celkem\n Total         36884         37021         NaN         NaN         NaN
# 16 - 19                   74           379         NaN         NaN         NaN
# 20 - 24                 2847          6370         NaN         NaN         NaN
# 25 - 29                12150         16395         NaN         NaN         NaN
# 30 - 34                12404          9401         NaN         NaN         NaN
# 35 - 39                 6365          3345         NaN         NaN         NaN
# 40 - 44                 1984           825         NaN         NaN         NaN
# 45 - 49                  586           167         NaN         NaN         NaN
# 50 - 54                  250            78         NaN         NaN         NaN
# 55+                      224            61         NaN         NaN         NaN
# Celkem\n Total           100           100         NaN         NaN         NaN
# 16 - 19             0.200629       1.02374         NaN         NaN         NaN
# 20 - 24              7.71879       17.2065         NaN         NaN         NaN
# 25 - 29              32.9411       44.2857         NaN         NaN         NaN
# 30 - 34              33.6298       25.3937         NaN         NaN         NaN
# 35 - 39              17.2568       9.03541         NaN         NaN         NaN
# 40 - 44              5.37903       2.22846         NaN         NaN         NaN
# 45 - 49              1.58876      0.451095         NaN         NaN         NaN
# 50 - 54             0.677801      0.210691         NaN         NaN         NaN
# 55+                 0.607309      0.164771         NaN         NaN         NaN
#
# [20 rows x 31 columns]

# %%
data.head()
# Out:
#                (1993, Groom) (1993, Bride) (2000, Groom) (2000, Bride)  \
# 0
# Celkem\n Total         51319         51450         41360         41528
# 16 - 19                 5809         20105           701          3008
# 20 - 24                28661         24770         14273         22765
# 25 - 29                11937          4734         18652         13093
# 30 - 34                 2913          1058          5061          1822
#
#                (2003, Groom) (2003, Bride) (2004, Groom) (2004, Bride)  \
# 0
# Celkem\n Total         36016         36371         37940         38147
# 16 - 19                  273          1503           264          1390
# 20 - 24                 7307         14212          6401         12892
# 25 - 29                18537         16724         19220         18799
# 30 - 34                 6951          3025          8715          4037
#
#                (2005, Groom) (2005, Bride)     ...     (2011, Bride)  \
# 0                                              ...
# Celkem\n Total         38347         38605     ...             33443
# 16 - 19                  220          1214     ...               474
# 20 - 24                 5342         11866     ...              6795
# 25 - 29                19128         19353     ...             15376
# 30 - 34                10103          5026     ...              8204
#
#                (2013, Groom) (2013, Bride) (2014, Groom) (2014, Bride)  \
# 0
# Celkem\n Total         32743         33029         34691         35155
# 16 - 19                   91           430            73           383
# 20 - 24                 2567          5961          2562          6026
# 25 - 29                11257         15045         11644         15778
# 30 - 34                11480          8282         12104          9075
#
#                (2015, Groom) (2015, Bride) (2015, nan) (2015, nan) (2015, nan)
# 0
# Celkem\n Total         36884         37021         NaN         NaN         NaN
# 16 - 19                   74           379         NaN         NaN         NaN
# 20 - 24                 2847          6370         NaN         NaN         NaN
# 25 - 29                12150         16395         NaN         NaN         NaN
# 30 - 34                12404          9401         NaN         NaN         NaN
#
# [5 rows x 31 columns]

# %%
data.index.str.replace('Celkem\n', '')
# Out:
# Index([' Total', '16 - 19', '20 - 24', '25 - 29', '30 - 34', '35 - 39',
#        '40 - 44', '45 - 49', '50 - 54', '55+', ' Total', '16 - 19', '20 - 24',
#        '25 - 29', '30 - 34', '35 - 39', '40 - 44', '45 - 49', '50 - 54',
#        '55+'],
#       dtype='object', name=0)

# %%
data.index = data.index.str.replace('Celkem\n', '')

# %%
data.head()
# Out:
#         (1993, Groom) (1993, Bride) (2000, Groom) (2000, Bride) (2003, Groom)  \
# 0
#  Total          51319         51450         41360         41528         36016
# 16 - 19          5809         20105           701          3008           273
# 20 - 24         28661         24770         14273         22765          7307
# 25 - 29         11937          4734         18652         13093         18537
# 30 - 34          2913          1058          5061          1822          6951
#
#         (2003, Bride) (2004, Groom) (2004, Bride) (2005, Groom) (2005, Bride)  \
# 0
#  Total          36371         37940         38147         38347         38605
# 16 - 19          1503           264          1390           220          1214
# 20 - 24         14212          6401         12892          5342         11866
# 25 - 29         16724         19220         18799         19128         19353
# 30 - 34          3025          8715          4037         10103          5026
#
#             ...     (2011, Bride) (2013, Groom) (2013, Bride) (2014, Groom)  \
# 0           ...
#  Total      ...             33443         32743         33029         34691
# 16 - 19     ...               474            91           430            73
# 20 - 24     ...              6795          2567          5961          2562
# 25 - 29     ...             15376         11257         15045         11644
# 30 - 34     ...              8204         11480          8282         12104
#
#         (2014, Bride) (2015, Groom) (2015, Bride) (2015, nan) (2015, nan)  \
# 0
#  Total          35155         36884         37021         NaN         NaN
# 16 - 19           383            74           379         NaN         NaN
# 20 - 24          6026          2847          6370         NaN         NaN
# 25 - 29         15778         12150         16395         NaN         NaN
# 30 - 34          9075         12404          9401         NaN         NaN
#
#         (2015, nan)
# 0
#  Total          NaN
# 16 - 19         NaN
# 20 - 24         NaN
# 25 - 29         NaN
# 30 - 34         NaN
#
# [5 rows x 31 columns]
